# %% [markdown]
#                                 Exercises with SQLite in Jupyter Notebook
#                                 - Analyizing Salaries in San Francisco -

# %%
# %load_ext sql

# %%
# %sql sqlite:////home/pitzm/Dokumentumok/database.sqlite

# %%
# %sql select name from sqlite_master where type='table'
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [('Salaries',)]

# %%
# %sql SELECT COUNT(*) as numberOfrows From Salaries
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(148654,)]

# %%
# %sql select * from Salaries limit 10
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(1, 'NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 0, 400184.25, '', 567595.43, 567595.43, 2011, '', 'San Francisco', ''),
#  (2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 245131.88, 137811.38, '', 538909.28, 538909.28, 2011, '', 'San Francisco', ''),
#  (3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 106088.18, 16452.6, '', 335279.91, 335279.91, 2011, '', 'San Francisco', ''),
#  (4, 'CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916, 56120.71, 198306.9, '', 332343.61, 332343.61, 2011, '', 'San Francisco', ''),
#  (5, 'PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 9737, 182234.59, '', 326373.19, 326373.19, 2011, '', 'San Francisco', ''),
#  (6, 'DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602, 8601, 189082.74, '', 316285.74, 316285.74, 2011, '', 'San Francisco', ''),
#  (7, 'ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 89062.9, 134426.14, '', 315981.05, 315981.05, 2011, '', 'San Francisco', ''),
#  (8, 'DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 0, 51322.5, '', 307899.46, 307899.46, 2011, '', 'San Francisco', ''),
#  (9, 'MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 86362.68, 40132.23, '', 303427.55, 303427.55, 2011, '', 'San Francisco', ''),
#  (10, 'JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262, 0, 17115.73, '', 302377.73, 302377.73, 2011, '', 'San Francisco', '')]

# %%
calc= %sql select BasePay+OvertimePay from Salaries limit 10
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.

# %%
calc
# Out:
# [(167411.18,),
#  (401097.9,),
#  (318827.31,),
#  (134036.71,),
#  (144138.6,),
#  (127203,),
#  (181554.90999999997,),
#  (256576.96,),
#  (263295.32,),
#  (285262,)]

# %%
# %sql select avg(TotalPay) from Salaries where Year=2011
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(71744.10387123664,)]

# %%
# %sql select JobTitle from Salaries group by JobTitle
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [('ACCOUNT CLERK',),
#  ('ACCOUNTANT',),
#  ('ACCOUNTANT INTERN',),
#  ('ACPO,JuvP, Juv Prob (SFERS)',),
#  ('ACUPUNCTURIST',),
#  ('ADMINISTRATIVE ANALYST',),
#  ('ADMINISTRATIVE ANALYST II',),
#  ('ADMINISTRATIVE ANALYST III',),
#  ('ADMINISTRATIVE ENGINEER',),
#  ('ADMINISTRATIVE SERVICES MANAGER',),
#  ('ADMINISTRATOR, SFGH MEDICAL CENTER',),
#  ('AFFIRMATIVE ACTION SPECIALIST',),
#  ('AGRICULTURAL INSPECTOR',),
#  ('AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI',),
#  ('AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS',),
#  ('AIRPORT COMMUNICATIONS OPERATOR',),
#  ('AIRPORT COMMUNICATIONS SUPERVISOR',),
#  ('AIRPORT ECONOMIC PLANNER',),
#  ('AIRPORT ELECTRICIAN',),
#  ('AIRPORT ELECTRICIAN SUPERVISOR',),
#  ('AIRPORT EMERGENCY PLANNING COORDINATOR',),
#  ('AIRPORT MECHANICAL MAINTENANCE SUPERVISOR',),
#  ('AIRPORT NOISE ABATEMENT SPECIALIST',),
#  ('AIRPORT OPERATIONS SUPERVISOR',),
#  ('AIRPORT POLICE SERVICES AIDE',),
#  ('AIRPORT PROPERTY SPECIALIST I',),
#  ('AIRPORT SAFETY OFFICER',),
#  ('ANESTHETIST',),
#  ('ANIMAL CARE ASSISTANT SUPERVISOR',),
#  ('ANIMAL CARE ATTENDANT',),
#  ('ANIMAL CARE SUPERVISOR',),
#  ('ANIMAL CONTROL OFFICER',),
#  ('ANIMAL HEALTH TECHNICIAN',),
#  ('ANIMAL KEEPER',),
#  ('APPRENTICE GARDENER',),
#  ('APPRENTICE STATIONARY ENGINEER',),
#  ('APPRENTICE STATIONARY ENGINEER, SEWAGE PLANT',),
#  ('APPRENTICE STATIONARY ENGINEER,WATER TREATMENT PLN',),
#  ('ARCHITECT',),
#  ('ARCHITECTURAL ADMINISTRATOR',),
#  ('ARCHITECTURAL ASSISTANT  I',),
#  ('ARCHITECTURAL ASSISTANT II',),
#  ('ARCHITECTURAL ASSOCIATE  I',),
#  ('ARCHITECTURAL ASSOCIATE II',),
#  ('AREA SUPERVISOR, PARKS, SQUARES AND FACILITIES',),
#  ('ARTS PROGRAM ASSISTANT',),
#  ('ASPHALT FINISHER',),
#  ('ASPHALT FINISHER SUPERVISOR I',),
#  ('ASPHALT PLANT SUPERVISOR I',),
#  ('ASPHALT WORKER',),
#  ('ASR Senior Office Specialist',),
#  ('ASR-Office Assistant',),
#  ('ASSESSMENT CLERK',),
#  ('ASSESSOR',),
#  ('ASSISTANT CHIEF ATTORNEY I',),
#  ('ASSISTANT CHIEF ATTORNEY II',),
#  ("ASSISTANT CHIEF DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',),
#  ('ASSISTANT CHIEF VICTIM/WITNESS INVESTIGATOR',),
#  ('ASSISTANT CLERK, BOARD OF SUPERVISORS',),
#  ('ASSISTANT CONSTRUCTION INSPECTOR',),
#  ('ASSISTANT COOK',),
#  ('ASSISTANT COUNSELOR',),
#  ('ASSISTANT COURT REPORTER COORDINATOR',),
#  ('ASSISTANT DEPUTY CHIEF II',),
#  ('ASSISTANT DEPUTY DIRECTOR, PORT',),
#  ('ASSISTANT DIRECTOR OF CLINICAL SERVICES I',),
#  ('ASSISTANT DIRECTOR OF CLINICAL SERVICES II',),
#  ('ASSISTANT DIRECTOR, JUVENILE HALL',),
#  ('ASSISTANT DIRECTOR, LOG CABIN RANCH',),
#  ('ASSISTANT ELECTRONIC MAINTENANCE TECHNICIAN',),
#  ('ASSISTANT ENGINEER',),
#  ('ASSISTANT FORENSIC TOXICOLOGIST I',),
#  ('ASSISTANT GENERAL SERVICES MANAGER',),
#  ('ASSISTANT HEALTH EDUCATOR',),
#  ('ASSISTANT INDUSTRIAL HYGIENIST',),
#  ('ASSISTANT INSPECTOR (POLICE DEPARTMENT)',),
#  ('ASSISTANT INSPECTOR II (POLICE DEPARTMENT)',),
#  ('ASSISTANT INSPECTOR III (POLICE DEPARTMENT)',),
#  ('ASSISTANT LAW LIBRARIAN',),
#  ('ASSISTANT MATERIALS COORDINATOR',),
#  ('ASSISTANT MEDICAL EXAMINER',),
#  ('ASSISTANT POWER HOUSE OPERATOR',),
#  ('ASSISTANT PURCHASER',),
#  ('ASSISTANT RECREATION DIRECTOR',),
#  ('ASSISTANT RECREATION SUPERVISOR',),
#  ('ASSISTANT RENTAL MANAGER, PORT',),
#  ('ASSISTANT RETIREMENT ANALYST',),
#  ('ASSISTANT SHERIFF',),
#  ('ASSISTANT STOREKEEPER',),
#  ('ASSISTANT SUPERINTENDENT RECREATION',),
#  ('ASSISTANT TO THE DIRECTOR, PUBLIC AFFAIRS       RS',),
#  ('ASSOCIATE AFFIRMATIVE ACTION COORDINATOR',),
#  ('ASSOCIATE AUDITOR',),
#  ('ASSOCIATE ENGINEER',),
#  ('ASSOCIATE HUMAN RESOURCES ANALYST',),
#  ('ASSOCIATE MUSEUM CONSERVATOR, ASIAN ART MUSEUM',),
#  ('ASSOCIATE MUSEUM REGISTRAR',),
#  ('ASSOCIATE PERFORMANCE AUDITOR',),
#  ('ASST. CHIEF PROBATION OFFICER-JUVENILE PROBATION',),
#  ('ASST. CHIEF, BUREAU OF CLAIMS INVEST. & ADMIN',),
#  ('ATTORNEY (CIVIL/CRIMINAL)',),
#  ('ATTORNEY FOR THE PUBLIC ADMINISTRATOR',),
#  ('ATTORNEY, TAX COLLECTOR',),
#  ('AUDIOLOGIST',),
#  ('AUDIOMETRIST',),
#  ('AUTOMOTIVE BODY AND FENDER WORKER',),
#  ('AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I',),
#  ('AUTOMOTIVE MACHINIST',),
#  ('AUTOMOTIVE MACHINIST ASSISTANT SUPERVISOR',),
#  ('AUTOMOTIVE MACHINIST SUPERVISOR I',),
#  ('AUTOMOTIVE MECHANIC',),
#  ('AUTOMOTIVE MECHANIC ASSISTANT SUPERVISOR',),
#  ('AUTOMOTIVE MECHANIC SUPERVISOR I',),
#  ('AUTOMOTIVE SERVICE WORKER',),
#  ('AUTOMOTIVE SERVICE WORKER ASSISTANT SUPERVISOR',),
#  ('AUTOMOTIVE TRANSIT SHOP SUPERVISOR I',),
#  ('Account Clerk',),
#  ('Accountant I',),
#  ('Accountant II',),
#  ('Accountant III',),
#  ('Accountant IV',),
#  ('Accountant Intern',),
#  ('Acupuncturist',),
#  ('Adm, SFGH Medical Center',),
#  ('Admin Analyst 3',),
#  ('Admin Hearing Examiner',),
#  ('Administrative Analyst',),
#  ('Administrative Analyst I',),
#  ('Administrative Analyst II',),
#  ('Administrative Engineer',),
#  ('Administrative Hearing Sup',),
#  ('Administrative Services Mgr',),
#  ('Administrator, DPH',),
#  ('Admission Attendant',),
#  ('Agricultural Inspector',),
#  ('Airport Communications Disp',),
#  ('Airport Communications Officer',),
#  ('Airport Economic Planner',),
#  ('Airport Electrician',),
#  ('Airport Electrician Supervisor',),
#  ('Airport Emerg Planning Coord',),
#  ('Airport Mechanical Maint Sprv',),
#  ('Airport Noise Abatement Spec',),
#  ('Airport Operations Supervisor',),
#  ('Airport Property Specialist 1',),
#  ('Airport Safety Officer',),
#  ('Airports Communications Sprv',),
#  ('Anesthetist',),
#  ('Animal Care Asst Supv',),
#  ('Animal Care Attendant',),
#  ('Animal Care Supervisor',),
#  ('Animal Control Officer',),
#  ('Animal Control Supervisor',),
#  ('Animal Health Technician',),
#  ('Animal Keeper',),
#  ('Apprentice Cement Mason I',),
#  ('Apprentice Gardener',),
#  ('Apprentice Stationary Engineer',),
#  ('Aprntc Statnry Eng, Sew Plant',),
#  ('AprntcStatnry Eng,WtrTreatPlnt',),
#  ('Aquatics Facility Asst Supv',),
#  ('Aquatics Facility Supervisor',),
#  ('Arborist Technician',),
#  ('Arborist Technician Supervisor',),
#  ('Arborist Technician Supv II',),
#  ('Architect',),
#  ('Architectural Administrator',),
#  ('Architectural Assistant 1',),
#  ('Architectural Assistant 2',),
#  ('Architectural Associate 1',),
#  ('Architectural Associate 2',),
#  ('Area Sprv Parks, Squares & Fac',),
#  ('Arts Program Assistant',),
#  ('Asphalt Finisher',),
#  ('Asphalt Finisher Supervisor 1',),
#  ('Asphalt Plant Supervisor 1',),
#  ('Asphalt Worker',),
#  ('Assessment Clerk',),
#  ('Assessor',),
#  ('Assessor-Recorder Office Spec',),
#  ('Assistant Chief Attorney 1',),
#  ('Assistant Chief Attorney 2',),
#  ('Assistant Const Inspector',),
#  ('Assistant Cook',),
#  ('Assistant Counselor',),
#  ('Assistant Deputy Chief 2',),
#  ('Assistant Director, Probate',),
#  ('Assistant Health Educator',),
#  ('Assistant Industrial Hygienist',),
#  ('Assistant Inspector',),
#  ('Assistant Inspector 2',),
#  ('Assistant Inspector 3',),
#  ('Assistant Law Librarian',),
#  ('Assistant Power House Operator',),
#  ('Assistant Purchaser',),
#  ('Assistant Recreation Director',),
#  ('Assistant Retirement Analyst',),
#  ('Assistant Sheriff',),
#  ('Assistant Storekeeper',),
#  ('Assoc Engineer',),
#  ('Assoc Musm Cnsrvt, AAM',),
#  ('Associate Museum Registrar',),
#  ("Asst Chf Dist Atty's Invstgtor",),
#  ('Asst Chf Prob Ofc, Juv Prob',),
#  ('Asst Chf Victim/Wit Invstgtor',),
#  ('Asst Chf of Dept (Fire Dept)',),
#  ('Asst Chf, Bur Clm Invest&Admin',),
#  ('Asst Clk, Board of Supervisors',),
#  ('Asst Dir Clinical Svcs 2',),
#  ('Asst Dir of Clinical Svcs 1',),
#  ('Asst Dir, Log Cabin Rnch',),
#  ('Asst Director, Juvenile Hall',),
#  ('Asst Electronic Main Tech',),
#  ('Asst Engr',),
#  ('Asst Forensic Toxicologist 1',),
#  ('Asst General Services Manager',),
#  ('Asst Materials Coordinator',),
#  ('Asst Med Examiner',),
#  ('Asst Superintendent Rec',),
#  ('Asst.Dep.Dir., Port',),
#  ('Attorney (Civil/Criminal)',),
#  ('Attorney, Tax Collector',),
#  ('Audiologist',),
#  ('Audiometrist',),
#  ('Auditor I',),
#  ('Auditor II',),
#  ('Auditor III',),
#  ('Auto Body & Fender Wrk Sprv 1',),
#  ('Auto Body&Fender Wrk Asst Sprv',),
#  ('Auto Machinist Asst Sprv',),
#  ('Auto Svc Wrk Asst Sprv',),
#  ('Automotive Body & Fender Wrk',),
#  ('Automotive Machinist',),
#  ('Automotive Machinist Sprv 1',),
#  ('Automotive Mechanic',),
#  ('Automotive Mechanic Asst Sprv',),
#  ('Automotive Mechanic Sprv 1',),
#  ('Automotive Service Worker',),
#  ('Automotive Trnst Shop Sprv 1',),
#  ('BACTERIOLOGICAL LABORATORY ASSISTANT',),
#  ('BAKER',),
#  ('BARBER',),
#  ('BATTALION CHIEF, (FIRE DEPARTMENT)',),
#  ('BEAUTICIAN',),
#  ('BENEFITS ANALYST',),
#  ('BENEFITS SUPERVISOR',),
#  ('BENEFITS TECHNICIAN',),
#  ('BIOLOGIST I/II',),
#  ('BIOLOGIST III',),
#  ('BOARD COMMISSION MEMBER, $200 PER MEETING',),
#  ('BOARD SECRETARY - MUNICIPAL TRANSPORTATION AGENC',),
#  ('BOARD/COMMISSION MEMBER, GROUP II',),
#  ('BOARD/COMMISSION MEMBER, GROUP III',),
#  ('BOARD/COMMISSION MEMBER, GROUP V',),
#  ('BOARD/COMMISSION SECRETARY III',),
#  ('BOOK REPAIRER',),
#  ('BRAILLIST',),
#  ('BRICKLAYER',),
#  ('BUILDING AND GROUNDS PATROL OFFICER',),
#  ('BUILDING INSPECTOR',),
#  ('BUILDING PLANS ENGINEER',),
#  ('BUILDING SERVICES TECHNICIAN',),
#  ('BUILDINGS AND GROUNDS MAINTENANCE SUPERINTENDENT',),
#  ('BUILDINGS AND GROUNDS MAINTENANCE SUPERVISOR',),
#  ('Baker',),
#  ('Barber',),
#  ('Battalion Chief, Fire Suppress',),
#  ('Battlion Chief, Fire Suppressi',),
#  ('Bd/Comm Secretary 3',),
#  ('BdComm Mbr, Grp2,M=$25/Mtg',),
#  ('BdComm Mbr, Grp3,M=$50/Mtg',),
#  ('BdComm Mbr, Grp5,M$100/Mo',),
#  ('Beautician',),
#  ('Benefits Analyst',),
#  ('Benefits Supervisor',),
#  ('Benefits Technician',),
#  ('Biologist',),
#  ('Biologist I/II',),
#  ('Biologist III',),
#  ('Bldg & Grounds Maint Sprv',),
#  ('Bldg & Grounds Patrol Officer',),
#  ('Bldgs & Grounds Maint Supt',),
#  ('Board Scty, MTA',),
#  ('Book Repairer',),
#  ('Braillist',),
#  ('Brd Comm Mbr, M=$200/Mtg',),
#  ('Bricklayer',),
#  ('Building Inspector',),
#  ('Building Plans Engineer',),
#  ('Building Services Technician',),
#  ('CABLE SPLICER',),
#  ('CAMP ASSISTANT',),
#  ('CAPTAIN III (POLICE DEPARTMENT)',),
#  ('CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE',),
#  ('CAPTAIN, EMERGENCYCY MEDICAL SERVICES',),
#  ('CAPTAIN, FIRE SUPPRESSION',),
#  ('CAR AND AUTO PAINTER',),
#  ('CARPENTER',),
#  ('CARPENTER SUPERVISOR I',),
#  ('CARPENTER SUPERVISOR II',),
#  ('CASHIER I',),
#  ('CASHIER II',),
#  ('CASHIER III',),
#  ('CEMENT FINISHER SUPERVISOR I',),
#  ('CEMENT FINISHER SUPERVISOR II',),
#  ('CEMENT MASON',),
#  ('CENTRAL PROCESSING AND DISTRIBUTION TECHNICIAN',),
#  ('CHEF',),
#  ('CHEMIST I/II',),
#  ('CHEMIST III',),
#  ('CHIEF ADULT PROBATION OFFICER',),
#  ('CHIEF ATTORNEY I (CIVIL & CRIMINAL)',),
#  ('CHIEF BUILDING INSPECTOR',),
#  ('CHIEF CLERK',),
#  ('CHIEF DEPUTY ADULT PROBATION OFFICER',),
#  ('CHIEF DEPUTY SHERIFF',),
#  ('CHIEF DIETITIAN',),
#  ("CHIEF DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('CHIEF ELECTRICAL INSPECTOR',),
#  ('CHIEF FIRE ALARM DISPATCHER',),
#  ('CHIEF HOUSING INSPECTOR',),
#  ('CHIEF MICROBIOLOGIST',),
#  ('CHIEF NURSERY SPECIALIST',),
#  ('CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',),
#  ('CHIEF OF POLICE',),
#  ('CHIEF PAYROLL AND PERSONNEL CLERK',),
#  ('CHIEF PLUMBING INSPECTOR',),
#  ('CHIEF PREPARATOR',),
#  ('CHIEF PROBATION OFFICER, JUVENILE COURT',),
#  ('CHIEF STATIONARY ENGINEER',),
#  ('CHIEF STATIONARY ENGINEER, SEWAGE PLANT',),
#  ('CHIEF STATIONARY ENGINEER, WATER TREATMENT PLANT',),
#  ('CHIEF SURVEYOR',),
#  ('CHIEF TELEPHONE OPERATOR',),
#  ('CHIEF VICTIM/WITNESS INVESTIGATOR',),
#  ('CHIEF WATER SERVICE INSPECTOR',),
#  ('CHILD CARE SPECIALIST',),
#  ('CHILD SUPPORT OFFICER II',),
#  ('CHILD SUPPORT OFFICER III',),
#  ('CITIZENS COMPLAINT OFFICER',),
#  ('CITY ATTORNEY',),
#  ('CITY PLANNING GRAPHICS SUPERVISOR',),
#  ('CITY PLANNING INTERN',),
#  ('CITY SHOPS ASSISTANT SUPERINTENDENT',),
#  ('CIVIL ENGINEERING ASSISTANT',),
#  ('CIVIL ENGINEERING ASSOCIATE I',),
#  ('CLAIMS ADJUSTER',),
#  ('CLAIMS INVESTIGATOR',),
#  ('CLAIMS INVESTIGATOR CITY ATTORNEYS OFFICE',),
#  ('CLAIMS PROCESS CLERK',),
#  ('CLERK',),
#  ('CLERK TYPIST',),
#  ('CLINICAL NURSE SPECIALIST',),
#  ('CLINICAL PHARMACIST',),
#  ('CLINICAL PSYCHOLOGIST',),
#  ('COLLECTIONS OFFICER',),
#  ('COMMANDER III, (POLICE DEPARTMENT)',),
#  ('COMMERCIAL DIVISION ASSISTANT SUPERVISOR',),
#  ('COMMISSIONER',),
#  ('COMMUNICATION LINE SUPERVISOR I',),
#  ('COMMUNICATIONS DIRECTOR',),
#  ('COMMUNICATIONS DISPATCHER I',),
#  ('COMMUNICATIONS DISPATCHER II',),
#  ('COMMUNICATIONS LINE WORKER SUPERVISOR II',),
#  ('COMMUNICATIONS SYSTEMS TECHNICIAN',),
#  ('COMMUNITY DEVELOPMENT ASSISTANT',),
#  ('COMMUNITY DEVELOPMENT SPECIALIST',),
#  ('CONFIDENTIAL CHIEF ATTORNEY II (CIVIL & CRIMINAL)',),
#  ('CONFIDENTIAL SECRETARY CITY ATTORNEY',),
#  ('CONFIDENTIAL SECRETARY TO DISTRICT ATTORNEY',),
#  ('CONSERVATORSHIP/CASE MGNT SUPV',),
#  ('CONSTRUCTION INSPECTOR',),
#  ('CONTRACT COMPLIANCE OFFICER I',),
#  ('CONTRACT COMPLIANCE OFFICER II',),
#  ('COOK',),
#  ('COORDINATOR OF CITIZEN INVOLVEMENT',),
#  ('COORDINATOR, HUMAN RIGHTS COMMISSION',),
#  ('COUNSELOR II',),
#  ('COUNSELOR, FAMILY COURT SERVICE',),
#  ('COUNSELOR, JUVENILE HALL',),
#  ('COUNSELOR, LOG CABIN RANCH',),
#  ('COURT AD RESOLUTION COORDINATOR',),
#  ('COURT ADMINISTRATIVE SECRETARY',),
#  ('COURT ADMINISTRATOR',),
#  ('COURT ALTERNATIVE SPECIALIST I',),
#  ('COURT ASSISTANT - SENIOR, SUPERIOR COURT',),
#  ('COURT ASSISTANT, SUPERIOR COURT',),
#  ('COURT CLERK',),
#  ('COURT COMMISSIONER',),
#  ('COURT COMPUTER APPLICATIONS ANALYST',),
#  ('COURT COMPUTER APPLICATIONS PROGRAMMER',),
#  ('COURT COMPUTER FACILITIES COORDINATOR',),
#  ('COURT COMPUTER SYSTEMS ENGINEER II',),
#  ('COURT COMPUTER SYSTEMS MANAGER',),
#  ('COURT EXECUTIVE OFFICER',),
#  ('COURT INTERPRETER',),
#  ('COURT INTERPRETER SUPERVISOR',),
#  ('COURT INVESTIGATOR',),
#  ('COURT MANAGER',),
#  ('COURT PARALEGAL',),
#  ('COURT REPORTER',),
#  ('COURT REPORTER COORDINATOR',),
#  ('COURT STAFF ATTORNEY II',),
#  ('COURT SUPERVISOR I',),
#  ('COURT SUPERVISOR II',),
#  ('COURT TRAINING SPECIALIST',),
#  ('CRAFTS INSTRUCTOR',),
#  ('CRANE MECHANIC SUPERVISOR',),
#  ('CRIME LABORATORY MANAGER',),
#  ('CRIMINAL JUSTICE SPECIALIST II',),
#  ('CRIMINALIST I',),
#  ('CRIMINALIST II',),
#  ('CRIMINALIST III',),
#  ('CURATOR I',),
#  ('CURATOR II',),
#  ('CURATOR III',),
#  ('CURATOR IV',),
#  ('CUSTODIAL ASSISTANT SUPERVISOR',),
#  ('CUSTODIAL SUPERVISOR',),
#  ('CUSTODIAN',),
#  ('CUSTOMER SERVICE AGENT SUPERVISOR',),
#  ('CUSTOMER SERVICE AGENT TRAINEE',),
#  ('Cable Splicer',),
#  ('Camp Assistant',),
#  ('Capt,Fire Prev or Fire Invsgtn',),
#  ('Captain 3',),
#  ('Captain, (Fire Department)',),
#  ('Captain, Emergency Med Svcs',),
#  ('Captain, Fire Suppression',),
#  ('Car and Auto Painter',),
#  ('Carpenter',),
#  ('Carpenter Supervisor 1',),
#  ('Carpenter Supervisor 2',),
#  ('Cashier 1',),
#  ('Cashier 2',),
#  ('Cashier 3',),
#  ('Cement Finisher Supervisor 1',),
#  ('Cement Finisher Supervisor 2',),
#  ('Cement Mason',),
#  ('Central Processing & Dist Tech',),
#  ('Cfdntal Chf Atty 2,(Cvl&Crmnl)',),
#  ('Cfdntal Sctry to City Atty',),
#  ('Cfdntal Sctry to Distric Atty',),
#  ('Chef',),
#  ('Chemist',),
#  ('Chemist I/II',),
#  ('Chemist III',),
#  ('Chf District Atty Investigator',),
#  ('Chf Payroll & Personnel Clerk',),
#  ('Chf Prob Ofc, Juv Court',),
#  ('Chf Stationary Eng, Sew Plant',),
#  ('Chf Statnry Eng,WtrTreat Plnt',),
#  ('Chf Victim/Witness Invstgtor',),
#  ('Chief Adult Probation Officer',),
#  ('Chief Atty1 (Civil & Criminal)',),
#  ('Chief Building Inspector',),
#  ('Chief Clerk',),
#  ('Chief Dep Adlt Prob Of (SFERS)',),
#  ('Chief Deputy Adlt Probation Of',),
#  ('Chief Deputy Sheriff',),
#  ('Chief Dietitian',),
#  ('Chief Electrical Inspector',),
#  ('Chief Fire Alarm Dispatcher',),
#  ('Chief Forensic Toxicologist',),
#  ('Chief Housing Inspector',),
#  ('Chief Investment Officer',),
#  ('Chief Nursery Specialist',),
#  ('Chief Plumbing Inspector',),
#  ('Chief Preparator',),
#  ('Chief Stationary Engineer',),
#  ('Chief Surveyor',),
#  ('Chief Telephone Operator',),
#  ('Chief Water Service Inspector',),
#  ('Chief of Police',),
#  ('Chief, Fire Department',),
#  ('Child Care Specialist',),
#  ('Child Support Officer I',),
#  ('Child Support Officer II',),
#  ('Child Support Officer III',),
#  ('Citizens Complaint Officer',),
#  ('City Attorney',),
#  ('City Planning Intern',),
#  ('City Shops Asst Superintendent',),
#  ('Civil Case Settlmnt Specialist',),
#  ('Claims Adjuster',),
#  ('Claims Investigator',),
#  ('Claims Investigator, CA',),
#  ('Claims Process Clerk',),
#  ('Clerk',),
#  ('Clerk Typist',),
#  ('Clinical Nurse Specialist',),
#  ('Clinical Pharmacist',),
#  ('Clinical Psychologist',),
#  ('Collection Supervisor',),
#  ('Collections Officer',),
#  ('Comm Pol Svcs Aide Supervisor',),
#  ('Commander 3',),
#  ('Commercial Div Asst Sprv',),
#  ('Commissioner 16.700c, No Pay',),
#  ('Commissioner No Benefits',),
#  ('Communication Line Sprv1',),
#  ('Communications Director',),
#  ('Communications Dispatcher 1',),
#  ('Communications Dispatcher 2',),
#  ('Communications Line Wrk Sprv 2',),
#  ('Communications Systems Tech',),
#  ('Community Development Asst',),
#  ('Community Development Spec',),
#  ('Community Police Services Aide',),
#  ('Conservatorship/Case Mgt Sprv',),
#  ('Construction Inspector',),
#  ('Contract Compliance Officer 1',),
#  ('Contract Compliance Officer 2',),
#  ('Controller',),
#  ('Conversion',),
#  ('Cook',),
#  ('Coord of Citizen Involvement',),
#  ('Coord, Human Rights Comm',),
#  ('Counselor 2',),
#  ('Counselor, Family Court Svc',),
#  ('Counselor, Juvenile Hall',),
#  ('Counselor, Juvenile Hall SFERS',),
#  ('Counselor, Log Cabin Ranch',),
#  ('Counselor,Log Cabin Rnch SFERS',),
#  ('Court Administrative Secretary',),
#  ('Court Administrator',),
#  ('Court Alternative Specialist 1',),
#  ('Court Asst-Sr, Superior Court',),
#  ('Court Asst., Superior Court',),
#  ('Court Clerk',),
#  ('Court Commissioner',),
#  ('Court Computer Sys Manager',),
#  ('Court Executive Officer',),
#  ('Court Interpreter',),
#  ('Court Interpreter Supervisor',),
#  ('Court Invstgtor, Superior Crt',),
#  ('Court Manager',),
#  ('Court Paralegal',),
#  ('Court Reporter',),
#  ('Court Reporter Coordinator',),
#  ('Court Staff Attorney II',),
#  ('Court Supervisor I',),
#  ('Court Supervisor II',),
#  ('Court Training Specialist',),
#  ('Crafts Instructor',),
#  ('Crane Mechanic Supervisor',),
#  ('Crime Lab Mgr',),
#  ('Criminal Justice Specialist 2',),
#  ('Criminalist I',),
#  ('Criminalist II',),
#  ('Criminalist III',),
#  ('Ct Comp App Analyst',),
#  ('Ct Comp App Programmer',),
#  ('Ct Comp Facilities Coord',),
#  ('Ct Comp Sys Engineer II',),
#  ('Curator 1',),
#  ('Curator 2',),
#  ('Curator 3',),
#  ('Curator 4',),
#  ('Custodial Assistant Supervisor',),
#  ('Custodial Supervisor',),
#  ('Custodian',),
#  ('Customer Service Agent',),
#  ('Customer Service Agent Supv',),
#  ('Customer Service Agent Trainee',),
#  ('DA Investigative Assist',),
#  ('DENTAL AIDE',),
#  ('DENTAL HYGIENIST',),
#  ('DENTIST',),
#  ('DEPARTMENT HEAD I',),
#  ('DEPARTMENT HEAD II',),
#  ('DEPARTMENT HEAD III',),
#  ('DEPARTMENT HEAD IV',),
#  ('DEPARTMENT HEAD V',),
#  ('DEPUTY CHIEF III (POLICE DEPARTMENT)',),
#  ('DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',),
#  ('DEPUTY COURT CLERK I',),
#  ('DEPUTY COURT CLERK II',),
#  ('DEPUTY COURT CLERK III',),
#  ('DEPUTY DIRECTOR I',),
#  ('DEPUTY DIRECTOR I - MUNICIPAL TRANSPORTATION AGE',),
#  ('DEPUTY DIRECTOR II',),
#  ('DEPUTY DIRECTOR II - MUNICIPAL TRANSPORTATION AG',),
#  ('DEPUTY DIRECTOR III',),
#  ('DEPUTY DIRECTOR IV',),
#  ('DEPUTY DIRECTOR OF INVESTMENTS',),
#  ('DEPUTY DIRECTOR V',),
#  ('DEPUTY PROBATION OFFICER',),
#  ('DEPUTY SEALER OF WEIGHTS AND MEASURES',),
#  ('DEPUTY SHERIFF',),
#  ('DIAGNOSTIC IMAGING TECH I',),
#  ('DIAGNOSTIC IMAGING TECH II',),
#  ('DIAGNOSTIC IMAGING TECH III',),
#  ('DIAGNOSTIC IMAGING TECH IV',),
#  ('DIETETIC TECHNICIAN',),
#  ('DIETITIAN',),
#  ('DIRECTOR OF ACTIVITIES, THERAPY AND VOLUNTEER SERV',),
#  ('DIRECTOR, EMPLOYEE RELATIONS DIVISION',),
#  ('DIRECTOR, FISCAL SERVICES',),
#  ('DIRECTOR, HUMAN RESOURCES',),
#  ('DIRECTOR, INFORMATION TECHNOLOGY GROUP',),
#  ('DIRECTOR, JUVENILE HALL',),
#  ('DIRECTOR, PROBATE',),
#  ('DIRECTOR, PROBATION SERVICES',),
#  ('DISABILITY ACCESS COORDINATOR',),
#  ('DISEASE CONTROL INVESTIGATOR',),
#  ('DISTRICT ATTORNEY',),
#  ("DISTRICT ATTORNEY'S INVESTIGATIVE ASSISTANT",),
#  ("DISTRICT ATTORNEY'S INVESTIGATOR",),
#  ('DIVISION DIRECTOR ADULT PROBATION',),
#  ('DOCUMENT EXAMINER TECHNICIAN',),
#  ('Dental Aide',),
#  ('Dental Hygienist',),
#  ('Dentist',),
#  ('Dep Chf of Dept (Fire Dept)',),
#  ('Dep Dir I',),
#  ('Dep Dir II',),
#  ('Dep Dir III',),
#  ('Dep Dir IV',),
#  ('Dep Dir V',),
#  ('Dep Dir for Investments, Ret',),
#  ('Dept Head I',),
#  ('Dept Head II',),
#  ('Dept Head III',),
#  ('Dept Head IV',),
#  ('Dept Head V',),
#  ('Depty Sealer of Weights & Meas',),
#  ('Deputy Chief 3',),
#  ('Deputy Court Clerk I',),
#  ('Deputy Court Clerk II',),
#  ('Deputy Court Clerk III',),
#  ('Deputy Dir I, MTA',),
#  ('Deputy Dir II, MTA',),
#  ('Deputy Probation Officer',),
#  ('Deputy Probation Officer SFERS',),
#  ('Deputy Sheriff',),
#  ('Deputy Sheriff (SFERS)',),
#  ('Deputy Sheriff 1',),
#  ('Diagnostic Imaging Tech I',),
#  ('Diagnostic Imaging Tech II',),
#  ('Diagnostic Imaging Tech III',),
#  ('Diagnostic Imaging Tech IV',),
#  ('Dietetic Technician',),
#  ('Dietitian',),
#  ('Dir Emp Relations Div',),
#  ('Dir of Act, Therapy & Vol Svcs',),
#  ('Dir, Log Cabin Ranch (SFERS)',),
#  ('Director, Fiscal Services',),
#  ('Director, Human Resources',),
#  ('Director, Info Tech Group',),
#  ('Director, Juvenile Hall',),
#  ('Director, Probate',),
#  ('Director, Probation Services',),
#  ('Disability Access Coordinator',),
#  ('Disease Control Investigator',),
#  ('Dist Atty Investigator (SFERS)',),
#  ('District Attorney',),
#  ("District Attry's Investigator",),
#  ('Div Director, Adult Probation',),
#  ('Document Examiner Technician',),
#  ('Drug Court Coordinator',),
#  ('Duty Officer',),
#  ('EEO Programs Specialist',),
#  ('EEO Senior Specialist',),
#  ('ELECTIONS CLERK',),
#  ('ELECTIONS WORKER',),
#  ('ELECTRIC MOTOR REPAIR SUPERVISOR I',),
#  ('ELECTRIC MOTOR REPAIRER',),
#  ('ELECTRICAL ENGINEERING ASSOCIATE I',),
#  ('ELECTRICAL INSPECTOR',),
#  ('ELECTRICAL LINE HELPER',),
#  ('ELECTRICAL LINE WORKER',),
#  ('ELECTRICAL TRANSIT MECHANIC SUPERVISOR I',),
#  ('ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR',),
#  ('ELECTRICAL TRANSIT SHOP SUPERVISOR I',),
#  ('ELECTRICAL TRANSIT SYSTEM MECHANIC',),
#  ('ELECTRICIAN',),
#  ('ELECTRICIAN SUPERVISOR I',),
#  ('ELECTRICIAN SUPERVISOR II',),
#  ('ELECTROENCEPHALOGRAPH TECHNICIAN I',),
#  ('ELECTRONIC INSTRUMENTATION TECHNICIAN,WTR PLTNCN',),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN',),
#  ('ELECTRONIC MAINTENANCE TECHNICIAN ASSISTANT SUPERV',),
#  ('ELEVATOR AND CRANE TECHNICIAN',),
#  ('ELIGIBILITY WORKER',),
#  ('ELIGIBILITY WORKER SUPERVISOR',),
#  ('EMERGENCY MEDICAL SERVICES AGENCY SPECIALIST',),
#  ('EMERGENCY PLANNING COORDINATOR',),
#  ('EMERGENCY PROTECTIVE ORDERS COMMISSIONER',),
#  ('EMPLOYEE ASSISTANCE COUNSELOR',),
#  ('EMPLOYEE RELATIONS REPRESENTATIVE',),
#  ('EMPLOYMENT & TRAINING SPECIALIST II',),
#  ('EMPLOYMENT & TRAINING SPECIALIST IV',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST I',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST III',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST V',),
#  ('EMPLOYMENT AND TRAINING SPECIALIST VI',),
#  ('EMT/Paramedic/Firefighter',),
#  ('ENGINEER',),
#  ('ENGINEERING ASSOCIATE II',),
#  ('ENVIRONMENT HEALTH TECHNICIAN II',),
#  ('ENVIRONMENT SPECIALIST',),
#  ('ENVIRONMENTAL ASSISTANT',),
#  ('ENVIRONMENTAL HEALTH INSPECTOR',),
#  ('ENVIRONMENTAL HEALTH TECHNICIAN I',),
#  ('ENVIRONMENTAL SERVICE WORKER',),
#  ('EPIDEMIOLOGIST I',),
#  ('EPIDEMIOLOGIST II',),
#  ('ESTATE INVESTIGATOR',),
#  ('EXECUTIVE ASSISTANT TO THE ADMINISTRATOR, S.F.G.H.',),
#  ('EXECUTIVE ASSISTANT TO THE GENERAL MANAGER, RETIRE',),
#  ('EXECUTIVE CONTRACT EMPLOYEE',),
#  ('EXECUTIVE DIRECTOR, SOUTHEAST COMMUNITY FACILITY',),
#  ('EXECUTIVE SECRETARY I',),
#  ('EXECUTIVE SECRETARY II',),
#  ('EXECUTIVE SECRETARY III',),
#  ('EXECUTIVE SECRETARY TO THE CONTROLLER',),
#  ('Elections Clerk',),
#  ('Elections Worker',),
#  ('Electr Instrmntn Tech Wtr Poll',),
#  ('Electr Maint Tech Asst Sprv',),
#  ('Electric Motor Repair Sprv 1',),
#  ('Electric Motor Repairer',),
#  ('Electrical Inspector',),
#  ('Electrical Line Helper',),
#  ('Electrical Line Worker',),
#  ('Electrical Transit Shop Sprv 1',),
#  ('Electrical Transit System Mech',),
#  ('Electrical Trnst Mech Sprv 1',),
#  ('Electrical Trnst Shop Sprv 1',),
#  ('Electrician',),
#  ('Electrician Supervisor 1',),
#  ('Electrician Supervisor 2',),
#  ('Electrician Supervisor II',),
#  ('Electrl Trnst Mech, Asst Sprv',),
#  ('Electroencephalograph Tech 1',),
#  ('Electronic Maintenance Tech',),
#  ('Elevator and Crane Technician',),
#  ('Eligibility Worker',),
#  ('Eligibility Worker Supervisor',),
#  ('Emergency Med Svcs Agency Spec',),
#  ('Emergency Medical Svcs Chief',),
#  ('Emergency Planning Coordinator',),
#  ('Emergency Services Assistant',),
#  ('Emergency Services Coord I',),
#  ('Emergency Services Coord II',),
#  ('Emergency Services Coord III',),
#  ('Emergency Services Coord IV',),
#  ('Emp & Training Spec 2',),
#  ('Emp & Training Spec 4',),
#  ('Employee Assistance Counselor',),
#  ('Employee Relations Representat',),
#  ('Employment & Training Spec 1',),
#  ('Employment & Training Spec 3',),
#  ('Employment & Training Spec 5',),
#  ('Employment & Training Spec 6',),
#  ('Eng/Arch/Landscape Arch Sr',),
#  ('Engineer',),
#  ('Engineer/Architect Principal',),
#  ('Engineering Assistant',),
#  ('Engineering Associate 1',),
#  ('Engineering Associate 2',),
#  ('Environmental Assistant',),
#  ('Environmental Health Inspector',),
#  ('Environmental Hlth Tech 1',),
#  ('Environmental Hlth Tech 2',),
#  ('Environmental Service Worker',),
#  ('Environmental Spec',),
#  ('Epidemiologist 1',),
#  ('Epidemiologist 2',),
#  ('Estate Investigator',),
#  ('Events & Facilities Specialist',),
#  ('Ex Asst to Admin, SFGH',),
#  ('Ex Asst to Ex Dir, Retirement',),
#  ('Ex Asst to the Controller',),
#  ('Ex Dir, SE Com Fac Comm',),
#  ('Executive Contract Employee',),
#  ('Executive Secretary 1',),
#  ('Executive Secretary 2',),
#  ('Executive Secretary 3',),
#  ('FARE COLLECTIONS RECEIVER',),
#  ('FARE INSPECTIONS SUPERVISOR/INVESTIGATOR',),
#  ('FARMER',),
#  ('FEASIBILITY ANALYST, PORT',),
#  ('FIELD SERVICES ASSISTANT SUPERVISOR',),
#  ('FINGERPRINT TECHNICIAN I',),
#  ('FINGERPRINT TECHNICIAN II',),
#  ('FINGERPRINT TECHNICIAN III',),
#  ('FIRE ALARM DISPATCHER',),
#  ('FIRE FIGHTER PARAMEDIC',),
#  ('FIRE PROTECTION ENGINEER',),
#  ('FIRE RESCUE PARAMEDIC',),
#  ('FIRE SAFETY INSPECTOR II',),
#  ('FIREFIGHTER',),
#  ('FISCAL SERVICES COORDINATOR',),
#  ('FISCAL TECHNICIAN',),
#  ('FOOD SERVICE MANAGER ADMINISTRATOR',),
#  ('FOOD SERVICE SUPERVISOR',),
#  ('FOOD SERVICE WORKER',),
#  ('FORENSIC AUTOPSY TECHNICIAN',),
#  ('FORENSIC LABORATORY TECHNICIAN',),
#  ('FORENSIC TOXICOLOGIST',),
#  ('FORESTER',),
#  ('FUSION WELDER',),
#  ('Fare Collections Receiver',),
#  ('Farmer',),
#  ('Feasibility Analyst, Port',),
#  ('Field Svcs Asst Supv',),
#  ('Fingerprint Technician 1',),
#  ('Fingerprint Technician 2',),
#  ('Fingerprint Technician 3',),
#  ('Fire Alarm Dispatcher',),
#  ('Fire Protection Engineer',),
#  ('Fire Rescue Paramedic',),
#  ('Fire Safety Inspector 2',),
#  ('Firefighter',),
#  ('Fiscal Services Supervisor',),
#  ('Fiscal Technician',),
#  ('Food Service Mgr Administrator',),
#  ('Food Service Supervisor',),
#  ('Food Service Worker',),
#  ('Forensic Autopsy Technician',),
#  ('Forensic Laboratory Technician',),
#  ('Forensic Toxicologist',),
#  ('Forensic Toxicologist Supervis',),
#  ('Forester',),
#  ('Fusion Welder',),
#  ('GARDENER',),
#  ('GENERAL LABORER',),
#  ('GENERAL LABORER SUPERVISOR I',),
#  ('GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',),
#  ('GENERAL UTILITY MECHANIC',),
#  ('GLAZIER',),
#  ('GLAZIER SUPERVISOR I',),
#  ('GOVERNMENT AND PUBLIC AFFAIRS MANAGER',),
#  ('GRAPHIC ARTIST',),
#  ('Gardener',),
#  ('Gen Mgr, Public Trnsp Dept',),
#  ('General Laborer',),
#  ('General Laborer Supervisor 1',),
#  ('General Utility Mechanic',),
#  ('Glazier',),
#  ('Glazier Supervisor 1',),
#  ('Govrnmt/Publ Affairs Mgr',),
#  ('Graphic Artist',),
#  ('Graphics Supervisor',),
#  ('HEAD AIRPORT ELECTRICIAN',),
#  ('HEAD ATTORNEY, CIVIL AND CRIMINAL',),
#  ('HEAD PARK PATROL OFFICER',),
#  ('HEAD PHOTOGRAPHER',),
#  ('HEALTH CARE ANALYST',),
#  ('HEALTH CARE BILLING CLERK I',),
#  ('HEALTH CARE BILLING CLERK II',),
#  ('HEALTH EDUCATOR',),
#  ('HEALTH PROGRAM COORDINATOR I',),
#  ('HEALTH PROGRAM COORDINATOR II',),
#  ('HEALTH PROGRAM COORDINATOR III',),
#  ('HEALTH PROGRAM PLANNER',),
#  ('HEALTH WORKER I',),
#  ('HEALTH WORKER II',),
#  ('HEALTH WORKER III',),
#  ('HEALTH WORKER IV',),
#  ('HEATING AND VENTILATING INSPECTOR',),
#  ('HEAVY EQUIPMENT OPERATIONS ASSISTANT SUPERVISOR',),
#  ('HEAVY EQUIPMENT OPERATIONS SUPERVISOR',),
#  ('HH Mechanical Shop Sprv',),
#  ('HODCARRIER',),
#  ('HOME HEALTH AIDE',),
#  ('HOSPITAL ELIGIBILITY WORKER',),
#  ('HOSPITAL ELIGIBILITY WORKER SUPERVISOR',),
#  ('HOUSEKEEPER/FOOD SERVICE CLEANER',),
#  ('HOUSING INSPECTOR',),
#  ('HSA Emp & Training Spec II',),
#  ('HSA Social Worker',),
#  ('HSA Sr Eligibility Worker',),
#  ('HUMAN RESOURCES DIRECTOR',),
#  ('HUMAN SERVICES TECHNICIAN',),
#  ('Head Airport Electrician',),
#  ('Head Atty, Civil & Criminal',),
#  ('Head Park Patrol Officer',),
#  ('Head Photographer',),
#  ('Health Care Analyst',),
#  ('Health Care Billing Clerk 1',),
#  ('Health Care Billing Clerk 2',),
#  ('Health Educator',),
#  ('Health Program Coordinator 1',),
#  ('Health Program Coordinator 2',),
#  ('Health Program Coordinator 3',),
#  ('Health Program Planner',),
#  ('Health Worker 1',),
#  ('Health Worker 2',),
#  ('Health Worker 3',),
#  ('Health Worker 4',),
#  ('Heating/Ventilating Inspector',),
#  ('Heavy Equip Ops Asst Sprv',),
#  ('Heavy Equipment Ops Sprv',),
#  ('Hodcarrier',),
#  ('Home Health Aide',),
#  ('Hospital Elig Wrk Supervisor',),
#  ('Hospital Eligibility Worker',),
#  ('Hospital Eligiblity Worker',),
#  ('Housekeeper/Food Service Clnr',),
#  ('Housing Inspector',),
#  ('Human Resources Director',),
#  ('Human Services Technician',),
#  ('ILLUSTRATOR AND ART DESIGNER',),
#  ('INCIDENT SUPPORT SPECIALIST',),
#  ('INDUSTRIAL HYGIENIST',),
#  ('INDUSTRIAL INJURY INVESTIGATOR',),
#  ('INFORMATION SERVICES MANAGER',),
#  ('INSPECTOR II, (POLICE DEPARTMENT)',),
#  ('INSPECTOR III, (POLICE DEPARTMENT)',),
#  ('INSPECTOR OF WEIGHTS AND MEASURES',),
#  ('INSPECTOR, (POLICE DEPARTMENT)',),
#  ('INSPECTOR, BUREAU OF FIRE PREVENTION AND PUBLIC SA',),
#  ('INSTITUTION UTILITY WORKER',),
#  ('INSTITUTIONAL POLICE LIEUTENANT',),
#  ('INSTITUTIONAL POLICE OFFICER',),
#  ('INSTITUTIONAL POLICE SERGEANT',),
#  ('INVENTORY CLERK',),
#  ('INVESTIGATOR, BUREAU OF FIRE INVESTIGATION',),
#  ('INVESTIGATOR, OFFICE OF CITIZEN COMPLAINTS',),
#  ('INVESTIGATOR, TAX COLLECTOR',),
#  ('INVESTIGATOR, TAXI & ACCESS SVCS',),
#  ('IS ADMINISTRATOR - SUPERVISOR',),
#  ('IS ADMINISTRATOR I',),
#  ('IS ADMINISTRATOR II',),
#  ('IS ADMINISTRATOR III',),
#  ('IS Administrator 1',),
#  ('IS Administrator 2',),
#  ('IS Administrator 3',),
#  ('IS Administrator-Supervisor',),
#  ('IS BUSINESS ANALYST',),
#  ('IS BUSINESS ANALYST - ASSISTANT',),
#  ('IS BUSINESS ANALYST - PRINCIPAL',),
#  ('IS BUSINESS ANALYST - SENIOR',),
#  ('IS Business Analyst',),
#  ('IS Business Analyst-Assistant',),
#  ('IS Business Analyst-Principal',),
#  ('IS Business Analyst-Senior',),
#  ('IS ENGINEER - ASSISTANT',),
#  ('IS ENGINEER - JOURNEY',),
#  ('IS ENGINEER - PRINCIPAL',),
#  ('IS ENGINEER - SENIOR',),
#  ('IS Engineer-Assistant',),
#  ('IS Engineer-Journey',),
#  ('IS Engineer-Principal',),
#  ('IS Engineer-Senior',),
#  ('IS Manager',),
#  ('IS OPERATOR - ANALYST',),
#  ('IS OPERATOR - JOURNEY',),
#  ('IS OPERATOR - SENIOR',),
#  ('IS OPERATOR - SUPERVISOR',),
#  ('IS Operator-Analyst',),
#  ('IS Operator-Journey',),
#  ('IS Operator-Senior',),
#  ('IS PROGRAMMER ANALYST',),
#  ('IS PROGRAMMER ANALYST - ASSISTANT',),
#  ('IS PROGRAMMER ANALYST - PRINCIPAL',),
#  ('IS PROGRAMMER ANALYST - SENIOR',),
#  ('IS PROJECT DIRECTOR',),
#  ('IS Prg Analyst-Principal',),
#  ('IS Program Analyst-Assistant',),
#  ('IS Programmer Analyst',),
#  ('IS Programmer Analyst-Senior',),
#  ('IS Project Director',),
#  ('IS TECHNICIAN - ASSISTANT',),
#  ('IS TECHNICIAN - JOURNEY',),
#  ('IS TECHNICIAN - SENIOR',),
#  ('IS TECHNICIAN - SUPERVISOR',),
#  ('IS TRAINER - ASSISTANT',),
#  ('IS TRAINER - JOURNEY',),
#  ('IS TRAINER - SENIOR',),
#  ('IS Technical-Journey',),
#  ('IS Technician Assistant',),
#  ('IS Technician-Senior',),
#  ('IS Technician-Supervisor',),
#  ('IS Trainer-Assistant',),
#  ('IS Trainer-Journey',),
#  ('IS Trainer-Senior',),
#  ('IT Operations Support Admin I',),
#  ('IT Operations Support Admin II',),
#  ('IT Operations Support Admin IV',),
#  ('IT Operations Support Admin V',),
#  ('IT Operations Support Admn III',),
#  ('Illustrator and Art Designer',),
#  ('Incident Support Specialist',),
#  ('Industrial Engineer',),
#  ('Industrial Hygienist',),
#  ('Industrial Injury Investigator',),
#  ('Insp, Fire Dept',),
#  ('Inspector 2',),
#  ('Inspector 3',),
#  ('Inspector, (Police Department)',),
#  ('Inspector, Weights & Measures',),
#  ('Institution Utility Worker',),
#  ('Institutional Police Officer',),
#  ('Institutional Police Sergeant',),
#  ('Instructional Designer',),
#  ...]

# %%
# %sql select avg(TotalPay) from Salaries where Year=2011 and JobTitle='ACCOUNTANT'
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(47429.268,)]

# %%
# %sql select avg(TotalPay) from Salaries where Year=2011 and JobTitle='ZOO CURATOR'
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(66686.56,)]

# %%
# %sql select avg(TotalPay) from Salaries where Year> 2011 and JobTitle in ('Curator 1', 'Curator 2', 'Curator 3', 'Curator 4')
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(68547.83428571424,)]

# %%
# %sql select avg(Benefits) from Salaries where (JobTitle='Engineer' or JobTitle='ENGINEER')
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(30108.90804761909,)]

# %%
# %sql select min(BasePay), max(BasePay) from Salaries where (JobTitle='Statistician')
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(31334.54, 78945.05)]

# %%
# %sql select count(distinct Year) from Salaries
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [(4,)]

# %%
# %sql select JobTitle, round(avg(TotalPay)) from Salaries where Year=2012 group by JobTitle order by avg(TotalPay) desc
# Out:
#  * sqlite:////home/pitzm/Dokumentumok/database.sqlite
# Done.
# [('Chief of Police', 321552.0),
#  ('Chief, Fire Department', 314760.0),
#  ('Gen Mgr, Public Trnsp Dept', 294000.0),
#  ('Executive Contract Employee', 273776.0),
#  ('Asst Chf of Dept (Fire Dept)', 270675.0),
#  ('Assistant Deputy Chief 2', 266246.0),
#  ('Asst Med Examiner', 264686.0),
#  ('Adm, SFGH Medical Center', 264365.0),
#  ('Deputy Chief 3', 263809.0),
#  ('Mayor', 260574.0),
#  ('Controller', 255697.0),
#  ('Dep Dir for Investments, Ret', 241613.0),
#  ('Port Director', 241569.0),
#  ('Emergency Medical Svcs Chief', 240064.0),
#  ('Dept Head V', 237181.0),
#  ('District Attorney', 227238.0),
#  ('Nursing Supervisor Psychiatric', 225959.0),
#  ('Wire Rope Cable Maint Sprv', 224833.0),
#  ('Battlion Chief, Fire Suppressi', 224414.0),
#  ('Dep Chf of Dept (Fire Dept)', 224254.0),
#  ('Cfdntal Chf Atty 2,(Cvl&Crmnl)', 217892.0),
#  ('Captain 3', 217361.0),
#  ('City Attorney', 216130.0),
#  ('Forensic Toxicologist', 214489.0),
#  ('Dept Head IV', 214381.0),
#  ('Commander 3', 213605.0),
#  ('Human Resources Director', 210280.0),
#  ('Public Defender', 207644.0),
#  ('Sheriff (SFERS)', 206652.0),
#  ('Chf Prob Ofc, Juv Court', 199227.0),
#  ('Captain, Fire Suppression', 198866.0),
#  ('Chief Atty1 (Civil & Criminal)', 198359.0),
#  ('Chief Adult Probation Officer', 197640.0),
#  ('Dir Emp Relations Div', 192837.0),
#  ('Incident Support Specialist', 191749.0),
#  ('Captain, Emergency Med Svcs', 189485.0),
#  ('Lieut,Fire Prev', 189236.0),
#  ('Court Executive Officer', 185055.0),
#  ('Project Manager 4', 181985.0),
#  ('Dep Dir V', 181297.0),
#  ('Manager VIII', 179936.0),
#  ('Assistant Inspector', 179345.0),
#  ('Lieutenant 3', 176921.0),
#  ('Lieutenant, Fire Suppression', 176791.0),
#  ('Assistant Chief Attorney 2', 176764.0),
#  ('Head Atty, Civil & Criminal', 176699.0),
#  ('Assistant Chief Attorney 1', 175700.0),
#  ('Attorney, Tax Collector', 173997.0),
#  ('Supervising Physician Spec', 171574.0),
#  ('Dept Head II', 171246.0),
#  ('Asst Chf Prob Ofc, Juv Prob', 170847.0),
#  ('Dept Head III', 169229.0),
#  ('Dep Dir IV', 168833.0),
#  ('Special Assistant 21', 166538.0),
#  ('Special Assistant 22', 166424.0),
#  ('Board Scty, MTA', 166164.0),
#  ('Assessor', 166010.0),
#  ('Deputy Dir I, MTA', 165406.0),
#  ('Treasurer', 165057.0),
#  ('Lieutenant 2', 164602.0),
#  ('Nurse Manager', 164282.0),
#  ('Director, Info Tech Group', 163349.0),
#  ('Insp, Fire Dept', 162815.0),
#  ('Manager VII', 162389.0),
#  ('Manager VIII, MTA', 160888.0),
#  ('Assistant Inspector 3', 160636.0),
#  ('IS Manager', 160527.0),
#  ('Water Const&Main Supt', 159972.0),
#  ('Assistant Inspector 2', 159835.0),
#  ('Sergeant 2', 159479.0),
#  ('Inspector, (Police Department)', 158693.0),
#  ("Sheriff's Captain", 157810.0),
#  ('Sergeant 3', 157234.0),
#  ('Trnst Power Line Wrk Sprv 2', 156038.0),
#  ('Dep Dir III', 154963.0),
#  ('Communications Line Wrk Sprv 2', 154789.0),
#  ('Inspector 3', 152624.0),
#  ('Transmission Line Supervisor 1', 152549.0),
#  ('Mayoral Staff XVII', 151278.0),
#  ('Inspector 2', 150570.0),
#  ('Marine Engineer of Fire Boats', 150468.0),
#  ('Deputy Dir II, MTA', 149797.0),
#  ('Fire Safety Inspector 2', 149675.0),
#  ('Supervising Pharmacist', 149226.0),
#  ('Airport Mechanical Maint Sprv', 149192.0),
#  ('Law Librarian', 148873.0),
#  ('Chief Deputy Sheriff', 148635.0),
#  ('Manager VI', 148451.0),
#  ('Anesthetist', 147754.0),
#  ('Firefighter', 146908.0),
#  ('Clinical Nurse Specialist', 146026.0),
#  ('Telecommunications Tech Supv', 145564.0),
#  ('Invstgtor,Fire Dept', 145484.0),
#  ('Sergeant, (Police Department)', 145310.0),
#  ('Heating/Ventilating Inspector', 145169.0),
#  ('Sr Light Rail Veh Equip Eng', 144790.0),
#  ('Sr Court Staff Attorney', 144360.0),
#  ('Sr Power Generation Tech', 144060.0),
#  ('Mech Shop & Equip Supt', 143204.0),
#  ("Sheriff's Lieutenant", 142809.0),
#  ('Asst Dir Clinical Svcs 2', 141458.0),
#  ('Asst Chf, Bur Clm Invest&Admin', 141360.0),
#  ('Court Computer Sys Manager', 141108.0),
#  ('Disability Access Coordinator', 140836.0),
#  ('Electrical Trnst Mech Sprv 1', 140817.0),
#  ('Crime Lab Mgr', 140449.0),
#  ('Engineer/Architect Principal', 140119.0),
#  ('Automotive Trnst Shop Sprv 1', 140069.0),
#  ('Train Controller', 138963.0),
#  ('Asst.Dep.Dir., Port', 138392.0),
#  ('Manager,Employee Relations Div', 137600.0),
#  ('Institutional Police Sergeant', 137495.0),
#  ('Manager VII, MTA', 137422.0),
#  ('Supt Water Treatment Fac', 136921.0),
#  ('Utility Plumber Supervisor 2', 136690.0),
#  ('Dept Head I', 136438.0),
#  ('Structural Engineer', 136327.0),
#  ('Special Assistant 16', 135740.0),
#  ('Transit Operations Specialist', 135734.0),
#  ('Eng/Arch/Landscape Arch Sr', 134368.0),
#  ('Operating Room Nurse', 134114.0),
#  ('Manager VI, MTA', 133819.0),
#  ('Project Manager 3', 133643.0),
#  ('Sprv Electronic Main Tech', 133415.0),
#  ('Attorney (Civil/Criminal)', 133389.0),
#  ('Radiologic Tech Sprv', 133152.0),
#  ('Director, Fiscal Services', 132582.0),
#  ('Chief Building Inspector', 132447.0),
#  ('Senior Electrical Inpsector', 132349.0),
#  ('Landscape Architect', 132239.0),
#  ('Chief Plumbing Inspector', 131831.0),
#  ('Fire Protection Engineer', 131757.0),
#  ('Power Generation Supervisor', 131670.0),
#  ('Criminalist III', 131588.0),
#  ('Electrical Trnst Shop Sprv 1', 131279.0),
#  ('Utility Plumber Supervisor 1', 130928.0),
#  ('Chief Water Service Inspector', 130734.0),
#  ('Transit Paint Shop Sprv1', 130606.0),
#  ('IS Engineer-Principal', 130204.0),
#  ('EMT/Paramedic/Firefighter', 130189.0),
#  ('Police Officer 2', 129862.0),
#  ('Auto Body & Fender Wrk Sprv 1', 129743.0),
#  ('Police Officer 3', 129077.0),
#  ('Principal Real Property Ofc', 129060.0),
#  ('Lab Svcs Mgr', 128337.0),
#  ('Manager V, MTA', 127735.0),
#  ('Court Reporter Coordinator', 127382.0),
#  ('Chief Electrical Inspector', 127263.0),
#  ('Communication Line Sprv1', 126737.0),
#  ('Power Generation Technician 2', 126658.0),
#  ('Traf Signal Electrician Sup II', 126621.0),
#  ('Electr Maint Tech Asst Sprv', 126495.0),
#  ('Diagnostic Imaging Tech III', 126388.0),
#  ('Manager V', 125975.0),
#  ('Director, Juvenile Hall', 124998.0),
#  ('Sewer Repair Supervisor', 124714.0),
#  ('Ex Asst to Ex Dir, Retirement', 124558.0),
#  ("Sheriff's Sergeant", 124553.0),
#  ('Public Relations Mgr', 123472.0),
#  ('Senior Physician Specialist', 122740.0),
#  ('Chief Dep Adlt Prob Of (SFERS)', 122662.0),
#  ('Manager IV', 122662.0),
#  ('Chief Fire Alarm Dispatcher', 122318.0),
#  ('Plumber Supervisor 2', 121826.0),
#  ('Trans Safety Specialist', 121562.0),
#  ('Electrl Trnst Mech, Asst Sprv', 121531.0),
#  ("Asst Chf Dist Atty's Invstgtor", 121171.0),
#  ('Transit Power Line Worker', 121076.0),
#  ('Bldgs & Grounds Maint Supt', 121070.0),
#  ('Electrician Supervisor 2', 120877.0),
#  ('Transit Power Line Sprv1', 120862.0),
#  ('Engineer', 120192.0),
#  ('Chief Housing Inspector', 120073.0),
#  ('Senior Plumbing Inspector', 119513.0),
#  ('Senior Deputy Sheriff', 119339.0),
#  ('Director, Probation Services', 119154.0),
#  ('Track Maint Wrk Sprv 1', 118671.0),
#  ('Automotive Mechanic Sprv 1', 118657.0),
#  ('Traf Signal Electrician Sup I', 118438.0),
#  ('Landscape Architect Assoc 2', 117922.0),
#  ('Assistant Law Librarian', 117639.0),
#  ('IS Project Director', 117546.0),
#  ('Chief Stationary Engineer', 117544.0),
#  ('Manager III', 117035.0),
#  ('Architect', 116969.0),
#  ('Director, Human Resources', 116213.0),
#  ('Airport Electrician Supervisor', 116187.0),
#  ('Senior Housing Inspector', 115938.0),
#  ('Asst Dir of Clinical Svcs 1', 115917.0),
#  ('Div Director, Adult Probation', 115899.0),
#  ('Senior Industrial Hygienist', 115681.0),
#  ('Automotive Mechanic Asst Sprv', 115647.0),
#  ('Communications Director', 115530.0),
#  ('Senior Comm Systems Technican', 115292.0),
#  ('Transit Manager 2', 115124.0),
#  ('Media/Security Syst Supv', 115001.0),
#  ('Mayoral Staff XVI', 114962.0),
#  ('IS Engineer-Senior', 114813.0),
#  ('Court Manager', 114694.0),
#  ('Ct Comp App Programmer', 114443.0),
#  ('Sr District Atty Investigator', 114440.0),
#  ("Med Examiner's InvestigatorIII", 114435.0),
#  ('Dep Dir I', 114345.0),
#  ('Diagnostic Imaging Tech II', 114306.0),
#  ('Sewage Treatment Plant Supt', 114279.0),
#  ('Clinical Pharmacist', 114056.0),
#  ('Real Estate Devt. Mgr, SFMTA', 113982.0),
#  ('Fire Rescue Paramedic', 113760.0),
#  ('Plumber Supervisor 1', 113503.0),
#  ('Airport Economic Planner', 113078.0),
#  ('Chf Stationary Eng, Sew Plant', 112839.0),
#  ('Project Manager 2', 112671.0),
#  ('Transit Supervisor', 112175.0),
#  ('Electronic Maintenance Tech', 112114.0),
#  ('Dep Dir II', 112026.0),
#  ('Senior Building Inspector', 112011.0),
#  ('Steamfitter Supervisor I', 111910.0),
#  ('Sr Statnry Eng, Wtr Treat Plnt', 111457.0),
#  ('Water Conservation Admin', 111404.0),
#  ('Plumbing Inspector', 111341.0),
#  ('Locksmith Supervisor 1', 111146.0),
#  ('Planner 5', 110866.0),
#  ('Supervising Mediator, UFCS', 110814.0),
#  ('Chf Victim/Witness Invstgtor', 110786.0),
#  ('Supv Biologist', 110681.0),
#  ('Pilot of Fire Boats', 110550.0),
#  ('Nursing Supervisor', 110454.0),
#  ('Senior Property Manager, Port', 110306.0),
#  ('Senior Plan Checker', 110123.0),
#  ('Employment & Training Spec 6', 109992.0),
#  ('Registered Nurse', 109597.0),
#  ('Senior Claims Investigator', 109372.0),
#  ('Ex Asst to Admin, SFGH', 109354.0),
#  ('Line Inspector', 109232.0),
#  ('Crane Mechanic Supervisor', 109024.0),
#  ('Architectural Administrator', 108934.0),
#  ('IS Business Analyst-Principal', 108836.0),
#  ('Manager IV, MTA', 108366.0),
#  ('Chf Statnry Eng,WtrTreat Plnt', 108190.0),
#  ('Senior Real Property Officer', 108093.0),
#  ('Contract Compliance Officer 2', 107857.0),
#  ('Chemist III', 107846.0),
#  ('Pr Environmental Hlth Insp', 107800.0),
#  ('Court Administrator', 107672.0),
#  ('IS Engineer-Journey', 107577.0),
#  ('Automotive Machinist Sprv 1', 107521.0),
#  ('Maritime Marketing Repr', 107458.0),
#  ('Bldg & Grounds Maint Sprv', 107015.0),
#  ('Biologist III', 106958.0),
#  ('Asst Superintendent Rec', 106851.0),
#  ('Transit Planner 4', 106808.0),
#  ('Sheet Metal Supervisor 1', 106453.0),
#  ('Ex Dir, SE Com Fac Comm', 106371.0),
#  ('Senior Occupational Therapist', 106336.0),
#  ('Special Assistant 15', 106285.0),
#  ('Claims Adjuster', 106076.0),
#  ('Pharmacist', 105824.0),
#  ('Research Psychologist', 105805.0),
#  ('Manager II', 105652.0),
#  ('Public Health Nurse', 105581.0),
#  ('Airport Electrician', 105566.0),
#  ('Maintenance Controller', 105476.0),
#  ('Mayoral Staff XIV', 105443.0),
#  ('Assoc Engineer', 105362.0),
#  ('Planner 4', 105297.0),
#  ('Sr Environmental Hlth Insp', 105173.0),
#  ('Senior Const Inspector', 105167.0),
#  ('Manager III, MTA', 105125.0),
#  ('Architectural Associate 2', 104974.0),
#  ('Special Assistant 19', 104962.0),
#  ('Sr. Stationary Eng, Sew Plant', 104478.0),
#  ('Maintenance Machinist Sprv 1', 104474.0),
#  ('Court Staff Attorney II', 104106.0),
#  ('Electrician Supervisor 1', 104042.0),
#  ('Municipal Stadium Groundskpr', 103966.0),
#  ('Auto Machinist Asst Sprv', 103936.0),
#  ('Elevator and Crane Technician', 103934.0),
#  ('Principal Mgmt Analyst', 103868.0),
#  ('Heavy Equipment Ops Sprv', 103862.0),
#  ('Perf Analyst III Project Mgr', 103770.0),
#  ('Safety Officer', 103744.0),
#  ('Public SafetyComm Supv', 103242.0),
#  ('Audiologist', 102991.0),
#  ('Parking Enforcement Admin', 102949.0),
#  ('Supervising Purchaser', 102708.0),
#  ('Housing Inspector', 102628.0),
#  ('Ct Comp App Analyst', 102599.0),
#  ('Communications Systems Tech', 102511.0),
#  ('Administrative Engineer', 102431.0),
#  ('Deputy Sheriff', 102391.0),
#  ('EEO Senior Specialist', 102323.0),
#  ('Fiscal Services Supervisor', 102246.0),
#  ('Court Interpreter Supervisor', 102246.0),
#  ('Electric Motor Repair Sprv 1', 101999.0),
#  ('Senior Water Service Inspector', 101331.0),
#  ('Electrical Transit System Mech', 101242.0),
#  ('Assistant Sheriff', 101030.0),
#  ('Manager I', 100983.0),
#  ('Chief Surveyor', 100928.0),
#  ('Utility Specialist', 100888.0),
#  ('Prnpl Admin Analyst II', 100863.0),
#  ('Member, Board of Supervisors', 100818.0),
#  ('Coord, Human Rights Comm', 100771.0),
#  ('Sr Community Dev Spec 2', 100688.0),
#  ('Building Inspector', 100653.0),
#  ('Carpenter Supervisor 1', 100644.0),
#  ('Power Plant Supervisor 1', 100229.0),
#  ('Airport Operations Supervisor', 100093.0),
#  ('Bd/Comm Secretary 3', 99916.0),
#  ('Soft Floor Coverer Supvr I', 99446.0),
#  ('IS Prg Analyst-Principal', 99382.0),
#  ('Sprv Clincal Psychologist', 99340.0),
#  ('Senior Emp Relations Repres', 99308.0),
#  ('Training Coordinator', 99167.0),
#  ('Sup Welfare Fraud Investigator', 99122.0),
#  ('Senior Stationary Engineer', 99026.0),
#  ('Water & Power Maint Sprv 1', 98937.0),
#  ('SrClaimsInvstgtor,Cty Atty Ofc', 98916.0),
#  ('Utility Plumber', 98860.0),
#  ('Maintenance Planner', 98808.0),
#  ('Street Inspection Supervisor', 98650.0),
#  ('Emergency Services Coord IV', 98484.0),
#  ('Electr Instrmntn Tech Wtr Poll', 98349.0),
#  ('Ornamental Iron Wrk Sprv 1', 98324.0),
#  ('Watershed Forester', 98243.0),
#  ('IS Engineer-Assistant', 98193.0),
#  ('Claims Investigator', 98033.0),
#  ('Emergency Med Svcs Agency Spec', 98004.0),
#  ('Transit Manager 1', 97829.0),
#  ('Asphalt Plant Supervisor 1', 97807.0),
#  ('Pr Real Property Appraiser', 97587.0),
#  ('Undersheriff', 97547.0),
#  ('Trans and Dist Line Worker', 97396.0),
#  ('Track Maint Supt, Muni Railway', 97342.0),
#  ('Protective Services Supervisor', 97340.0),
#  ('Senior Physical Therapist', 97301.0),
#  ('Principal Environ Specialist', 97281.0),
#  ('Fusion Welder', 97191.0),
#  ('Coord of Citizen Involvement', 97106.0),
#  ('Mayoral Staff XIII', 96769.0),
#  ('Sprv Wastewater Cont Inspector', 96661.0),
#  ('Sprv Adult Probation Ofc', 96634.0),
#  ('Police Officer', 96633.0),
#  ('Heavy Equip Ops Asst Sprv', 96472.0),
#  ('Sr Counselor, Juvenile Hall', 96253.0),
#  ('Safety Analyst', 96175.0),
#  ('Wire Rope Cable Maint Mechanic', 95882.0),
#  ('Cement Finisher Supervisor 1', 95762.0),
#  ('Senior Health Educator', 95649.0),
#  ('Street Environ Svcs Oprs Supv', 95584.0),
#  ("Med Examiner's Investigator II", 95552.0),
#  ('Supervising Parts Storekeeper', 95446.0),
#  ('Medical Social Work Supervisor', 95342.0),
#  ('Carpenter Supervisor 2', 95095.0),
#  ('Steamfitter', 94932.0),
#  ('Nurse Practitioner', 94858.0),
#  ('Glazier Supervisor 1', 94758.0),
#  ('Area Sprv Parks, Squares & Fac', 94496.0),
#  ('Architectural Associate 1', 94483.0),
#  ('Court Training Specialist', 94377.0),
#  ('Senior Street Inspector', 94371.0),
#  ('Conservatorship/Case Mgt Sprv', 94115.0),
#  ('Supv Chemist', 94095.0),
#  ('Shelter Veterinarian', 93972.0),
#  ('Sr Investigator, OCC', 93717.0),
#  ('Administrative Services Mgr', 93612.0),
#  ('Pub Safety Communication Coord', 93574.0),
#  ('Airports Communications Sprv', 93526.0),
#  ('Pr Administrative Analyst', 93504.0),
#  ('Secretary, Comm on the Environ', 93236.0),
#  ('Probate Examiner', 93229.0),
#  ('Hospital Elig Wrk Supervisor', 93215.0),
#  ('Sr Public Defenders Invstgtor', 93124.0),
#  ('IS Business Analyst-Senior', 92804.0),
#  ('Water Operations Analyst', 92537.0),
#  ('Industrial Hygienist', 92242.0),
#  ('Car and Auto Painter', 91832.0),
#  ('Power House Operator', 91692.0),
#  ('Head Park Patrol Officer', 91576.0),
#  ('Auditor III', 91504.0),
#  ('Pr Investigator, Tax Collector', 91463.0),
#  ('Planner 4-Environmental Review', 91453.0),
#  ('Feasibility Analyst, Port', 91442.0),
#  ('Painter Supervisor 1', 91258.0),
#  ('Plumber', 91197.0),
#  ('Automotive Mechanic', 91087.0),
#  ('Traffic Sign Manager', 91043.0),
#  ('Chf Payroll & Personnel Clerk', 90892.0),
#  ('Water Service Inspector', 90729.0),
#  ('Librarian 2 - Asian Arts', 90618.0),
#  ('Construction Inspector', 90557.0),
#  ('Curator 4', 90541.0),
#  ('Asst Forensic Toxicologist 1', 90538.0),
#  ('Public SafetyComm Disp', 90428.0),
#  ('Court Supervisor II', 90359.0),
#  ('Sprv, Traffic & Street Signs', 90040.0),
#  ('Project Manager 1', 89772.0),
#  ('Criminalist II', 89727.0),
#  ('IS Trainer-Senior', 89644.0),
#  ('IS Administrator 3', 89613.0),
#  ('Pr Fare Collections Receiver', 89392.0),
#  ('Sr Airport Communications Disp', 89328.0),
#  ('Electrical Line Worker', 89162.0),
#  ('Mental Health Hearing Officer', 89084.0),
#  ('Mayoral Staff XV', 89029.0),
#  ('Secretary, Library Commission', 88790.0),
#  ('Ex Asst to the Controller', 88790.0),
#  ('Main Machinist Asst Sprv', 88770.0),
#  ('Rent Board Supervisor', 88768.0),
#  ('Diagnostic Imaging Tech IV', 88744.0),
#  ('Survey Associate', 88696.0),
#  ('Counselor, Family Court Svc', 88647.0),
#  ('Sprv Prob Ofc, Juv Court', 88599.0),
#  ('Sr Employee Asst Counselor', 88589.0),
#  ('Senior Microbiologist', 88327.0),
#  ('Welfare Fraud Investigator', 88277.0),
#  ('Arborist Technician Supervisor', 88269.0),
#  ('Operating Engineer, Universal', 88188.0),
#  ('Sr General Utility Mechanic', 88148.0),
#  ('Employment & Training Spec 5', 88123.0),
#  ('Power Generation Technician 1', 88117.0),
#  ('Librarian 3', 88022.0),
#  ('Asst Dir, Log Cabin Rnch', 87961.0),
#  ('Market Research Spec, Port', 87945.0),
#  ('Environmental Health Inspector', 87938.0),
#  ('Asst Clk, Board of Supervisors', 87908.0),
#  ('Airport Property Specialist 1', 87888.0),
#  ('IS Technician-Supervisor', 87480.0),
#  ('Sewer Service Worker', 87255.0),
#  ('Mgr, Unified Family Court Svcs', 87195.0),
#  ('IS Administrator-Supervisor', 87133.0),
#  ('Chief Nursery Specialist', 87024.0),
#  ('Program Specialist Supervisor', 86950.0),
#  ('Sr Cent Proc & Dist Tech', 86904.0),
#  ('Accountant IV', 86903.0),
#  ('Arborist Technician Supv II', 86887.0),
#  ('Automotive Body & Fender Wrk', 86750.0),
#  ('Cfdntal Sctry to Distric Atty', 86658.0),
#  ('Biologist I/II', 86656.0),
#  ('Chief Dietitian', 86621.0),
#  ('Roofer Supervisor 1', 86578.0),
#  ('Sr Marriage, Fam & Cld Cnslr', 86572.0),
#  ('Media Training Specialist', 86528.0),
#  ('Senior Medical Social Worker', 86469.0),
#  ('Traffic Signal Electrician', 86324.0),
#  ('Station Agent, Muni Railway', 86277.0),
#  ('Property Manager, Port', 86231.0),
#  ('Sup Ct Admin Secretary', 86211.0),
#  ('Sr. Environmental Spec', 86072.0),
#  ('Medical Records Tech Sprv', 86061.0),
#  ('Auto Svc Wrk Asst Sprv', 85971.0),
#  ('Pr Personal Property Auditor', 85799.0),
#  ('Claims Investigator, CA', 85774.0),
#  ('Chf District Atty Investigator', 85694.0),
#  ('Sr Personal Property Auditor', 85676.0),
#  ('IS Programmer Analyst-Senior', 85658.0),
#  ('Sr Psychiatric Social Worker', 85533.0),
#  ('Stationary Eng, Sewage Plant', 85287.0),
#  ('Patient Accounts Manager', 85267.0),
#  ('Utility Plumber Apprentice', 85208.0),
#  ('IT Operations Support Admin IV', 85153.0),
#  ('Pattern Maker', 85118.0),
#  ('Transit Car Cleaner Asst Sprv', 85031.0),
#  ('Dir of Act, Therapy & Vol Svcs', 85007.0),
#  ('Child Support Officer III', 84854.0),
#  ('Planner 3', 84785.0),
#  ('Electric Motor Repairer', 84776.0),
#  ('Mental Hlth Treatment Spec', 84773.0),
#  ('Employee Assistance Counselor', 84755.0),
#  ('Vet Laboratory Technologist', 84755.0),
#  ('Asst Engr', 84752.0),
#  ('Court Supervisor I', 84750.0),
#  ("Worker's Comp Supervisor 1", 84724.0),
#  ('Senior Personnel Analyst', 84575.0),
#  ('Parking Meter Repairer Sprv 1', 84550.0),
#  ('Cfdntal Sctry to City Atty', 84351.0),
#  ('Training Technician', 84198.0),
#  ('Health Program Coordinator 3', 84160.0),
#  ('Switch Repairer', 84155.0),
#  ('Maintenance Machinist', 84130.0),
#  ('Senior Purchaser', 84065.0),
#  ("District Attry's Investigator", 84013.0),
#  ('Govrnmt/Publ Affairs Mgr', 83917.0),
#  ('Materials Coordinator', 83901.0),
#  ('Bricklayer', 83760.0),
#  ('Security Analyst', 83758.0),
#  ('Protective Services Worker', 83518.0),
#  ('Manager II, MTA', 83494.0),
#  ('Cable Splicer', 82710.0),
#  ('Planner 3-Environmental Review', 82680.0),
#  ('Senior Health Program Planner', 82679.0),
#  ('Commercial Div Asst Sprv', 82469.0),
#  ('Airport Communications Disp', 82376.0),
#  ('Senior Real Property Appraiser', 82354.0),
#  ('Electrician', 82233.0),
#  ('Secretary, Health Commission', 82149.0),
#  ('Transit Planner III', 82043.0),
#  ('Victim/Witness Investigator 3', 81999.0),
#  ('Comm Pol Svcs Aide Supervisor', 81930.0),
#  ('Assistant Industrial Hygienist', 81770.0),
#  ('Senior Estate Investigator', 81538.0),
#  ('Electrical Inspector', 81480.0),
#  ('Court Clerk', 81316.0),
#  ('Watershed Keeper Supervisor', 81132.0),
#  ('Ct Comp Sys Engineer II', 81130.0),
#  ('Asst Chf Victim/Wit Invstgtor', 81016.0),
#  ('Court Invstgtor, Superior Crt', 80916.0),
#  ('Electrical Line Helper', 80909.0),
#  ('Automotive Machinist', 80859.0),
#  ('Pipe Welder', 80835.0),
#  ('Med Staff Svcs Dept Anl', 80782.0),
#  ('Stationary Engineer', 80692.0),
#  ('Mayoral Staff XII', 80607.0),
#  ('IS Business Analyst', 80603.0),
#  ('Pr Payroll & Personnel Clerk', 80565.0),
#  ('Institutional Police Officer', 80547.0),
#  ('Locksmith', 80292.0),
#  ('Maintenance Manager', 80235.0),
#  ('IS Trainer-Journey', 80127.0),
#  ('Assoc Musm Cnsrvt, AAM', 80116.0),
#  ('Microbiologist', 79991.0),
#  ('Librarian 2', 79978.0),
#  ('Social Work Supervisor', 79769.0),
#  ('Animal Care Supervisor', 79632.0),
#  ('Senior Administrative Analyst', 79504.0),
#  ('Engineering Associate 2', 79496.0),
#  ('Court Asst., Superior Court', 79235.0),
#  ('Street Repair Supervisor 2', 79139.0),
#  ('Deputy Court Clerk III', 78873.0),
#  ('Welder', 78704.0),
#  ('Customer Service Agent Supv', 78599.0),
#  ('Surgical Procedures Technician', 78581.0),
#  ('Physician Assistant', 78449.0),
#  ('Food Service Mgr Administrator', 78260.0),
#  ('Accountant III', 78010.0),
#  ('Principal Personnel Analyst', 77556.0),
#  ('Building Services Technician', 77554.0),
#  ('Legal Secretary 2', 77540.0),
#  ('Criminal Justice Specialist 2', 77517.0),
#  ('AprntcStatnry Eng,WtrTreatPlnt', 77481.0),
#  ('PrDAInvest,SpecUnit (SFERS)', 77149.0),
#  ('Survey Assistant II', 76961.0),
#  ('Epidemiologist 2', 76870.0),
#  ('Investigator,Taxi & AccessSvcs', 76670.0),
#  ('Media Production Supv', 76623.0),
#  ('Chemist I/II', 76559.0),
#  ('Court Administrative Secretary', 76550.0),
#  ('Environmental Hlth Tech 2', 76403.0),
#  ('Airport Safety Officer', 76376.0),
#  ('Asphalt Finisher Supervisor 1', 76372.0),
#  ('Carpenter', 76370.0),
#  ('Sr. Community Devl Spc 1', 76367.0),
#  ('Sheet Metal Worker', 76223.0),
#  ('Eligibility Worker Supervisor', 75966.0),
#  ('Integrated Pest Mgmt Specialst', 75900.0),
#  ('Contract Compliance Officer 1', 75664.0),
#  ('Public Relations Officer', 75615.0),
#  ('Forensic Laboratory Technician', 75485.0),
#  ('Court Reporter', 75419.0),
#  ('Chief Preparator', 75362.0),
#  ('IS Technician-Senior', 75260.0),
#  ('Counselor 2', 74891.0),
#  ('Prpl Permit and Citation Clerk', 74741.0),
#  ('Mail & Reproduction Svc Sprv', 74622.0),
#  ('Health Educator', 74618.0),
#  ('Emp & Training Spec 4', 74510.0),
#  ('Sr Fare Collections Receiver', 74463.0),
#  ('Illustrator and Art Designer', 74160.0),
#  ('Senior Transit Traffic Checker', 74127.0),
#  ('Janitorial Svcs Asst Sprv', 74118.0),
#  ('Rep, Comm Status of Women', 74077.0),
#  ('Museum Sec Supv', 74032.0),
#  ('Training Officer', 73730.0),
#  ('Pile Worker', 73593.0),
#  ('Rehabilitation Svcs Coord', 73585.0),
#  ('Recreation Supervisor', 73560.0),
#  ('Principal Parts Storekeeper', 73459.0),
#  ("Public Defender's Investigator", 73416.0),
#  ('Window Cleaner Supervisor', 73329.0),
#  ('Real Property Manager', 73242.0),
#  ('Chef', 73207.0),
#  ('Senior Psychiatric Orderly', 73111.0),
#  ("Worker's Compensation Adjuster", 72943.0),
#  ('General Utility Mechanic', 72827.0),
#  ('Deputy Probation Officer', 72804.0),
#  ('Track Maintenance Worker', 72777.0),
#  ('Legislation Clerk', 72774.0),
#  ('Auditor II', 72751.0),
#  ('Piledriver Supervisor 1', 72718.0),
#  ('Graphics Supervisor', 72597.0),
#  ('Nursing Assistant', 72541.0),
#  ('Program Specialist', 72206.0),
#  ('Senior Museum Registrar', 72157.0),
#  ('Senior Parking Control Officer', 72050.0),
#  ('Mayoral Staff XI', 71973.0),
#  ('Senior Power House Operator', 71895.0),
#  ('Program Support Analyst', 71891.0),
#  ('Asst Materials Coordinator', 71773.0),
#  ('Acupuncturist', 71749.0),
#  ('Pharmacy Technician', 71616.0),
#  ('Assistant Retirement Analyst', 71529.0),
#  ('Field Svcs Asst Supv', 71429.0),
#  ('Maintenance Scheduler', 71403.0),
#  ('Public Health Team Leader', 71355.0),
#  ('Investigator, Tax Collector', 71276.0),
#  ('Depty Sealer of Weights & Meas', 71264.0),
#  ('Piledriver Engine Operator', 71263.0),
#  ('Marriage, Family & Child Cnslr', 70880.0),
#  ('Forensic Autopsy Technician', 70828.0),
#  ('Engineering Associate 1', 70755.0),
#  ('Principal Water Services Clerk', 70741.0),
#  ('Janitorial Services Supervisor', 70666.0),
#  ('Nursery Specialist', 70654.0),
#  ('Transit Car Cleaner', 70597.0),
#  ('Porter Supervisor 1', 70426.0),
#  ('Ornamental Iron Worker', 70347.0),
#  ('Automotive Service Worker', 70336.0),
#  ('Mayoral Staff IX', 70283.0),
#  ('Statnry Eng Water Treat Plant', 70256.0),
#  ('Senior Social Worker', 70197.0),
#  ('Senior Fiscal Technician', 70164.0),
#  ('Psychiatric Social Worker', 70021.0),
#  ('Arborist Technician', 70008.0),
#  ('Library Technical Assistant 2', 69745.0),
#  ('Aquatics Facility Supervisor', 69680.0),
#  ('Senior Pharmacy Helper', 69647.0),
#  ('Regulatory Specialist', 69622.0),
#  ('Park Section Supervisor', 69606.0),
#  ('Patient Accounts Supervisor', 69589.0),
#  ('Environmental Spec', 69535.0),
#  ('Senior Book Repairer', 69426.0),
#  ('Wastewater Control Inspector', 69383.0),
#  ('Senior Management Assistant', 69093.0),
#  ('Water QualityTech I/II', 69017.0),
#  ('Senior Parts Storekeeper', 68974.0),
#  ('Sprv Adult Prob Ofc (SFERS)', 68881.0),
#  ('Chief Clerk', 68872.0),
#  ('Principal Account Clerk', 68828.0),
#  ('Administrative Analyst', 68773.0),
#  ('EEO Programs Specialist', 68739.0),
#  ('Health Care Analyst', 68702.0),
#  ('Mobile Equipment Supervisor', 68662.0),
#  ('Glazier', 68578.0),
#  ('Senior Morgue Attendant', 68517.0),
#  ('Performance Analyst II', 68494.0),
#  ('Media Programming Spec', 68480.0),
#  ('IS Business Analyst-Assistant', 68471.0),
#  ('Water Meter Repairer', 68289.0),
#  ('Medical Social Worker', 68241.0),
#  ('Head Airport Electrician', 68233.0),
#  ('Transit Planner 2', 68156.0),
#  ('Landscape Architect Assoc 1', 68033.0),
#  ('Truck Driver', 67836.0),
#  ('IS Administrator 1', 67794.0),
#  ('Estate Investigator', 67782.0),
#  ('Mayoral Staff X', 67642.0),
#  ('Sr Human Resources Analyst', 67522.0),
#  ('Airport Noise Abatement Spec', 67516.0),
#  ('Benefits Supervisor', 67474.0),
#  ('Personnel/Payroll Repres', 67440.0),
#  ('Water Quality Tech III', 67288.0),
#  ('Fare Collections Receiver', 67277.0),
#  ('IS Administrator 2', 67162.0),
#  ('Roofer', 67159.0),
#  ('Community Development Spec', 67145.0),
#  ('Metalsmith', 67067.0),
#  ('Baker', 67020.0),
#  ('Curator 3', 67007.0),
#  ('Social Work Specialist', 66886.0),
#  ('Senior Eligibility Worker', 66869.0),
#  ('Investigator/Transit Fare Supv', 66828.0),
#  ('Invstgtor Ofc Citizen Cmplnts', 66796.0),
#  ('Planner 2', 66791.0),
#  ('Fiscal Technician', 66764.0),
#  ('Shelter Officer Supervisor', 66709.0),
#  ('Accountant I', 66633.0),
#  ('Research Assistant', 66542.0),
#  ('Senior Food Service Supervisor', 66537.0),
#  ('Community Police Services Aide', 66537.0),
#  ('Curator 2', 66418.0),
#  ('Hodcarrier', 66350.0),
#  ('Health Program Coordinator 2', 66247.0),
#  ('Executive Secretary 2', 66225.0),
#  ('Architectural Assistant 2', 66095.0),
#  ('Real Property Appraiser', 66089.0),
#  ('Pharmacy Helper', 66068.0),
#  ('Public Information Officer', 65825.0),
#  ('Snr Permit and Citation Clerk', 65754.0),
#  ('Criminalist I', 65723.0),
#  ('Health Worker 4', 65696.0),
#  ('Physical Therapist', 65633.0),
#  ('Transit Operator', 65525.0),
#  ('Sr Payroll & Personnel Clerk', 65516.0),
#  ('Child Support Officer II', 65357.0),
#  ('Custodial Supervisor', 65353.0),
#  ('Citizens Complaint Officer', 65279.0),
#  ('Emp & Training Spec 2', 65148.0),
#  ('IS Operator-Senior', 65142.0),
#  ('Executive Secretary 1', 65007.0),
#  ('Street Inspector', 64923.0),
#  ('Dental Hygienist', 64895.0),
#  ('Personal Property Auditor', 64661.0),
#  ('IS Technical-Journey', 64632.0),
#  ('Personnel Technician', 64609.0),
#  ('Clinical Psychologist', 64607.0),
#  ('Asst Electronic Main Tech', 64592.0),
#  ('Orthopedic Technician 2', 64569.0),
#  ('Hospital Eligiblity Worker', 64445.0),
#  ('Parts Storekeeper', 64428.0),
#  ('Purchaser', 64374.0),
#  ('Wharfinger 2', 64180.0),
#  ('Traffic Survey Technician', 64158.0),
#  ('Forester', 64109.0),
#  ('Occupational Therapist', 64097.0),
#  ('Senior Benefits Analyst', 64052.0),
#  ('General Laborer Supervisor 1', 63936.0),
#  ('Med Staff Svcs Dept Spc', 63856.0),
#  ('Accountant II', 63848.0),
#  ('Central Processing & Dist Tech', 63755.0),
#  ('Food Service Supervisor', 63326.0),
#  ('Assistant Const Inspector', 63205.0),
#  ('Apprentice Stationary Engineer', 63201.0),
#  ('Watershed Keeper', 63117.0),
#  ('Health Program Coordinator 1', 63068.0),
#  ('Painter', 62986.0),
#  ('Airport Emerg Planning Coord', 62984.0),
#  ('Aprntc Statnry Eng, Sew Plant', 62981.0),
#  ('Sr Opers Mgr', 62965.0),
#  ('Physician Specialist', 62964.0),
#  ('Assistant Health Educator', 62905.0),
#  ('Management Assistant', 62868.0),
#  ('Principal Clerk', 62707.0),
#  ('Specialist in Aging 2', 62643.0),
#  ('Deputy Court Clerk II', 62526.0),
#  ('Assistant Counselor', 62337.0),
#  ('Senior Maintenance Controller', 62334.0),
#  ('Medical Records Technician', 62328.0),
#  ('Elections Worker', 62306.0),
#  ('Personnel Analyst', 62284.0),
#  ('Senior Unit Clerk', 62281.0),
#  ('Sr Medical Transcriber Typist', 62241.0),
#  ('Events & Facilities Specialist', 62000.0),
#  ('Farmer', 61967.0),
#  ('Principal Museum Preparator', 61962.0),
#  ('Victim/Witness Investigator 2', 61920.0),
#  ('Chief Telephone Operator', 61877.0),
#  ('Supv Bldg Grounds Patrol Ofcr', 61761.0),
#  ('Legal Assistant', 61647.0),
#  ('Court Alternative Specialist 1', 61628.0),
#  ('Animal Keeper', 61608.0),
#  ('Victim/Witness Investigator 1', 61580.0),
#  ('Rep, Human Rights Comm', 61565.0),
#  ('Employment & Training Spec 3', 61548.0),
#  ('Employment & Training Spec 1', 61390.0),
#  ('Health Care Billing Clerk 2', 61322.0),
#  ('Research Asst, Superior Court', 61203.0),
#  ('Sheet Metal Wrk Supervisor 2', 60812.0),
#  ('Executive Secretary 3', 60375.0),
#  ('Sewer Maintenance Worker', 60356.0),
#  ('Psychiatric Technician', 60301.0),
#  ('Diagnostic Imaging Tech I', 60194.0),
#  ('Physical Therapist Assistant', 60157.0),
#  ('Survey Assistant I', 60065.0),
#  ('Patient Accounts Clerk', 59961.0),
#  ('Transit Information Clerk', 59884.0),
#  ('Architectural Assistant 1', 59788.0),
#  ('Library Technical Assistant 1', 59648.0),
#  ('Benefits Analyst', 59570.0),
#  ('Counselor, Log Cabin Ranch', 59556.0),
#  ('Therapy Aide', 59454.0),
#  ('Licensed Vocational Nurse', 59385.0),
#  ('Senior Personnel Clerk', 59364.0),
#  ('Nutritionist', 59264.0),
#  ('Collections Officer', 59240.0),
#  ('Speech Pathologist', 59199.0),
#  ('IS Operator-Journey', 59192.0),
#  ('Senior Collections Officer', 59170.0),
#  ('IS Operator-Analyst', 59160.0),
#  ('Window Cleaner', 59151.0),
#  ('ASR Senior Office Specialist', 59097.0),
#  ('Customer Service Agent', 58910.0),
#  ('Court Interpreter', 58843.0),
#  ('Legal Secretary 1', 58796.0),
#  ('Cement Mason', 58661.0),
#  ('Shelter Office Asst Supv', 58596.0),
#  ('Medical Transcriber Typist', 58533.0),
#  ('Junior Engineer', 58458.0),
#  ('Disease Control Investigator', 58336.0),
#  ('Laboratory Technician II', 58215.0),
#  ('Environmental Hlth Tech 1', 58117.0),
#  ('Senior Offset Machine Operator', 57961.0),
#  ('Fingerprint Technician 3', 57922.0),
#  ('Agricultural Inspector', 57826.0),
#  ('Transit Traffic Checker', 57754.0),
#  ('Assessor-Recorder Office Spec', 57650.0),
#  ('Parking Control Officer', 57641.0),
#  ('Animal Care Asst Supv', 57617.0),
#  ('Offset Machine Operator', 57584.0),
#  ('Youth Comm Advisor', 57545.0),
#  ('Payroll Clerk', 57508.0),
#  ('Senior Laundry Worker', 57491.0),
#  ('Asst General Services Manager', 57278.0),
#  ('Dentist', 57150.0),
#  ('Shade and Drapery Worker', 57124.0),
#  ('Fingerprint Technician 2', 57075.0),
#  ('Sr Materials & Supplies Sprv', 57009.0),
#  ('IS Programmer Analyst', 57003.0),
#  ('Materials Testing Technician', 56884.0),
#  ('Secretary 2', 56517.0),
#  ('Legislative Assistant', 56321.0),
#  ('Patient Accounts Asst Sprv', 56230.0),
#  ('Community Development Asst', 55996.0),
#  ('Senior Water Services Clerk', 55894.0),
#  ('Utility Analyst', 55841.0),
#  ('Stable Attendant', 55547.0),
#  ('Volunteer/Outreach Coord', 55522.0),
#  ('Senior Account Clerk', 55471.0),
#  ('Human Services Technician', 55282.0),
#  ('Dietitian', 55231.0),
#  ('Permit and Citation Clerk', 55144.0),
#  ('Parking Meter Repairer', 55064.0),
#  ('Braillist', 54914.0),
#  ('Transcriber Typist', 54877.0),
#  ('Meter Reader', 54761.0),
#  ('Health Program Planner', 54633.0),
#  ('DA Investigative Assist', 54572.0),
#  ('Planner Technician', 54482.0),
#  ('Health Care Billing Clerk 1', 54474.0),
#  ('Unit Clerk', 54421.0),
#  ('Medical Records Clerk', 54245.0),
#  ('Asphalt Finisher', 54241.0),
#  ('Employee Relations Representat', 54004.0),
#  ('Laboratory Technician I', 53932.0),
#  ('Inventory Clerk', 53847.0),
#  ('Custodial Assistant Supervisor', 53757.0),
#  ('Dietetic Technician', 53743.0),
#  ('Engineering Assistant', 53743.0),
#  ('Dental Aide', 53645.0),
#  ('Gardener', 53599.0),
#  ('Librarian 1', 53533.0),
#  ('X-Ray Laboratory Aide', 53492.0),
#  ('Secretary 1', 53362.0),
#  ('Photographer', 53361.0),
#  ('Director, Probate', 53270.0),
#  ('Inspector, Weights & Measures', 53145.0),
#  ('Senior Storekeeper', 53122.0),
#  ('General Laborer', 53095.0),
#  ('Senior Transcriber Typist', 52840.0),
#  ('Patient Svcs Finance Tech', 52752.0),
#  ('Administrative Analyst II', 52377.0),
#  ('Health Worker 3', 52326.0),
#  ('Sctry, Juv Probation Comm', 52048.0),
#  ('Materials/Supplies Supervisor', 52002.0),
#  ('Associate Museum Registrar', 51988.0),
#  ('Epidemiologist 1', 51835.0),
#  ('Sr. Microphoto/Imaging Tech.', 51770.0),
#  ('Sign Worker', 51723.0),
#  ('Marina Assistant Manager', 51545.0),
#  ('Accountant Intern', 51230.0),
#  ('Book Repairer', 51151.0),
#  ('Mayoral Staff V', 50982.0),
#  ('Rehabilitation Counselor', 50814.0),
#  ('Fingerprint Technician 1', 50769.0),
#  ('Transit Fare Inspector', 50580.0),
#  ('Assistant Storekeeper', 50527.0),
#  ('Nurses Staffing Assistant', 50516.0),
#  ('Building Plans Engineer', 50322.0),
#  ('Dist Atty Investigator (SFERS)', 50182.0),
#  ('Parking Hearing Examiner', 50006.0),
#  ('Supply Room Attendant', 49515.0),
#  ('Senior Clerk Typist', 49479.0),
#  ('Recreation Coordinator', 49384.0),
#  ('Health Worker 2', 49382.0),
#  ('Court Asst-Sr, Superior Court', 49368.0),
#  ('Lighting Fixture Maint Worker', 49245.0),
#  ('Benefits Technician', 49160.0),
#  ('Senior Legal Process Clerk', 48812.0),
#  ('Special Assistant 3', 48716.0),
#  ('Patient Care Assistant', 48498.0),
#  ('Assistant Power House Operator', 48223.0),
#  ('Eligibility Worker', 48219.0),
#  ('Senior Museum Preparator', 48193.0),
#  ('Court Commissioner', 48051.0),
#  ('Media/Security Sys Spec', 47909.0),
#  ('Junior Administrative Analyst', 47796.0),
#  ('Junior Clerk Typist', 47088.0),
#  ('Asphalt Worker', 46979.0),
#  ('Sctry, Bldg Inspection Comm', 46841.0),
#  ('Graphic Artist', 46720.0),
#  ('Junior Management Assistant', 46681.0),
#  ('Account Clerk', 46067.0),
#  ('Sr Transit Information Clerk', 46031.0),
#  ('Communications Dispatcher 2', 45546.0),
#  ('Porter Assistant Supervisor', 45537.0),
#  ('Telephone Operator', 45492.0),
#  ('Medical Evaluations Assistant', 45484.0),
#  ('IS Program Analyst-Assistant', 45327.0),
#  ('Senior Food Service Worker', 45176.0),
#  ('IS Trainer-Assistant', 45013.0),
#  ('Health Worker 1', 44833.0),
#  ('Assistant Purchaser', 44503.0),
#  ('Senior Clerk', 44446.0),
#  ('Clerk Typist', 44411.0),
#  ('Bldg & Grounds Patrol Officer', 44275.0),
#  ('Tile Setter', 44126.0),
#  ('Cashier 2', 44072.0),
#  ('Chief Deputy Adlt Probation Of', 43804.0),
#  ('Planner 1', 43791.0),
#  ('Emergency Planning Coordinator', 43704.0),
#  ('Library Assistant', 43652.0),
#  ('Custodian', 43639.0),
#  ('Environmental Assistant', 43636.0),
#  ('Storekeeper', 43487.0),
#  ('Child Care Specialist', 43476.0),
#  ('Park Patrol Officer', 43219.0),
#  ('Urban Forestry Inspector', 42908.0),
#  ('Principal Recreation Sprv', 42848.0),
#  ('Curator 1', 42757.0),
#  ('Victim & Witness Technician', 42665.0),
#  ('Collection Supervisor', 42455.0),
#  ('Cook', 42286.0),
#  ('Police Services Aide', 42236.0),
#  ('Institution Utility Worker', 42153.0),
#  ('Materials Testing Aide', 42013.0),
#  ('Traffic Signal Operator', 41773.0),
#  ('Microphoto/Imaging Technician', 41676.0),
#  ('Porter', 41480.0),
#  ('Animal Control Officer', 41169.0),
#  ('Painter Supervisor 2', 40964.0),
#  ('Assistant Director, Probate', 40919.0),
#  ('ASR-Office Assistant', 40788.0),
#  ('Housekeeper/Food Service Clnr', 40757.0),
#  ('Admin Analyst 3', 40704.0),
#  ('Beautician', 40625.0),
#  ('Counselor, Juvenile Hall', 40246.0),
#  ('Signal and Systems Engineer', 39565.0),
#  ('Home Health Aide', 39146.0),
#  ('Head Photographer', 38815.0),
#  ('Personnel Clerk', 38737.0),
#  ('Legal Process Clerk', 38473.0),
#  ('Social Worker', 38004.0),
#  ('Security Guard', 37991.0),
#  ('Recreation Specialist', 37642.0),
#  ('Museum Registrar', 37402.0),
#  ('Aquatics Facility Asst Supv', 37390.0),
#  ('Crafts Instructor', 37041.0),
#  ('Legislative Calendar Clerk', 36961.0),
#  ('Stores & Equip Asst Sprv', 36923.0),
#  ('Document Examiner Technician', 36610.0),
#  ('Electroencephalograph Tech 1', 36309.0),
#  ('Senior Telephone Operator', 36074.0),
#  ('Fire Alarm Dispatcher', 35995.0),
#  ('Animal Care Attendant', 35946.0),
#  ('Communications Dispatcher 1', 35603.0),
#  ('Food Service Worker', 35238.0),
#  ("Sheriff's Cadet", 34851.0),
#  ('Asst Director, Juvenile Hall', 34815.0),
#  ('Mayoral Staff II', 34603.0),
#  ('Industrial Injury Investigator', 34544.0),
#  ('Clerk', 33543.0),
#  ('Ct Comp Facilities Coord', 33514.0),
#  ('Elections Clerk', 33343.0),
#  ('Assessment Clerk', 33327.0),
#  ('Media Production Tech', 32945.0),
#  ('Public Relations Assistant', 32758.0),
#  ('Special Nurse', 32744.0),
#  ('Sctry, Human Svcs. Commission', 31484.0),
#  ('Arts Program Assistant', 31403.0),
#  ('Statistician', 31335.0),
#  ('Swimming Instr/Pool Lifeguard', 31195.0),
#  ('Nurse Midwife', 30914.0),
#  ('Cashier 1', 30891.0),
#  ("Med Examiner's Investigator I", 30871.0),
#  ('Museum Guard', 30823.0),
#  ('Dir, Log Cabin Ranch (SFERS)', 30519.0),
#  ('Claims Process Clerk', 30017.0),
#  ('Wharfinger 1', 29629.0),
#  ('Respiratory Care Practitioner', 28867.0),
#  ('Apprentice Gardener', 27946.0),
#  ('Mayoral Staff VII', 27766.0),
#  ('Audiometrist', 27480.0),
#  ('Special Assistant 14', 27165.0),
#  ('Customer Service Agent Trainee', 26197.0),
#  ('Senior Assessment Clerk', 26033.0),
#  ('Shelter Service Rep', 24941.0),
#  ('Admission Attendant', 24338.0),
#  ('Deputy Probation Officer SFERS', 23590.0),
#  ('Museum Preparator', 22651.0),
#  ('Deputy Sheriff 1', 22633.0),
#  ('Pr DistAtty Invstgtor,SpecUnit', 21802.0),
#  ('Court Paralegal', 21673.0),
#  ('Soft Floor Coverer', 20842.0),
#  ('Assistant Cook', 20504.0),
#  ('Environmental Service Worker', 20283.0),
#  ('Library Page', 19707.0),
#  ('PS Aide to Prof', 19044.0),
#  ('Special Assistant 10', 17365.0),
#  ('StdntDsgn Train2/Arch/Eng/Plng', 16640.0),
#  ('Public Service Aide-Admin', 15833.0),
#  ('StdntDsgnTrain3, Arch/Eng/Plng', 15540.0),
#  ...]
